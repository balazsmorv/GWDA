# %%
"""
NCI1 ↔ NCI109 Domain Adaptation Template
----------------------------------------
1) Load NCI1 (source) and NCI109 (target)
2) Train a small GCN on source only
3) *** PLACEHOLDER *** for your (F)GW-based adaptation
4) Evaluate on target

Switch source/target by swapping dataset names at the top.
"""

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, global_add_pool
import torch_geometric.transforms as T
from sklearn.metrics import accuracy_score

# ----------------------------
# Config
# ----------------------------
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
DATA_ROOT = './data'
SOURCE_NAME = 'NCI1'
TARGET_NAME = 'NCI109'
BATCH_SIZE = 64
LR = 1e-3
EPOCHS = 200
HIDDEN = 64
TRAIN_RATIO = 0.8
OH_DEGREE = 8  # one-hot degree cap (keeps features simple & consistent)

# %%
# ----------------------------
# 1) Load datasets (+ robust node features)
# ----------------------------
# Use OneHotDegree to guarantee x exists even if raw features are missing.
import os, certifi
os.environ["SSL_CERT_FILE"] = certifi.where()
transform = T.OneHotDegree(max_degree=OH_DEGREE, cat=False)
src_ds = TUDataset(root=DATA_ROOT, name=SOURCE_NAME, transform=transform)
tgt_ds = TUDataset(root=DATA_ROOT, name=TARGET_NAME, transform=transform)

# Ensure identical feature dimensions across domains (replace, don't concat)
assert src_ds.num_features == tgt_ds.num_features, f"Feature dim mismatch: src={src_ds.num_features}, tgt={tgt_ds.num_features}. Use OneHotDegree(..., cat=False) or pad features."
in_dim = src_ds.num_features

print(f"Source: {SOURCE_NAME} -> {len(src_ds)} graphs, x_dim={src_ds.num_features}, classes={src_ds.num_classes}")
print(f"Target: {TARGET_NAME} -> {len(tgt_ds)} graphs, x_dim={tgt_ds.num_features}, classes={tgt_ds.num_classes}")

num_classes = src_ds.num_classes  # NCI1/NCI109 are binary

# Simple random split
def split_dataset(ds, ratio=TRAIN_RATIO):
    n = len(ds)
    perm = torch.randperm(n)
    n_tr = int(ratio * n)
    return ds[perm[:n_tr]], ds[perm[n_tr:]]

src_train, src_test = split_dataset(src_ds)
tgt_train, tgt_test = split_dataset(tgt_ds)

# Limit training graphs for speed / scalability
SRC_LIMIT = 200
TGT_LIMIT = 200
if len(src_train) > SRC_LIMIT:
    src_train = src_train[:SRC_LIMIT]
if len(tgt_train) > TGT_LIMIT:
    tgt_train = tgt_train[:TGT_LIMIT]
print(f"Using {len(src_train)} source-train and {len(tgt_train)} target-train graphs (capped at 200 each).")

src_loader = DataLoader(src_train, batch_size=BATCH_SIZE, shuffle=True)
src_test_loader = DataLoader(src_test, batch_size=BATCH_SIZE, shuffle=False)
tgt_loader = DataLoader(tgt_train, batch_size=BATCH_SIZE, shuffle=True)
tgt_test_loader = DataLoader(tgt_test, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Source: NCI1 -> 4110 graphs, x_dim=9, classes=2
# Target: NCI109 -> 4127 graphs, x_dim=9, classes=2
# Using 200 source-train and 200 target-train graphs (capped at 200 each).

# %%
# ----------------------------
# 2) Define a minimal GCN classifier
# ----------------------------
class SimpleGCN(nn.Module):
    def __init__(self, in_channels, hidden, classes):
        super().__init__()
        # Two GCNConv layers for neighborhood aggregation
        self.conv1 = GCNConv(in_channels, hidden)
        self.conv2 = GCNConv(hidden, hidden)
        self.lin = nn.Linear(hidden, classes)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv2(x, edge_index))
        x = global_add_pool(x, batch)
        return self.lin(x)

model = SimpleGCN(in_dim, HIDDEN, num_classes).to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr=LR)

# %%
# ----------------------------
# 3) Train on SOURCE only
# ----------------------------
def train_epoch(loader):
    model.train()
    total = 0.0
    for data in loader:
        data = data.to(DEVICE)
        optimizer.zero_grad()
        out = model(data)
        loss = F.cross_entropy(out, data.y)
        loss.backward()
        optimizer.step()
        total += loss.item() * data.num_graphs
    return total / len(loader.dataset)

for ep in range(1, EPOCHS + 1):
    loss = train_epoch(src_loader)
    if ep % 5 == 0:
        print(f"[Pretrain] Epoch {ep}/{EPOCHS}  loss={loss:.4f}")

print("Source-only pretraining done.")
# Out:
# [Pretrain] Epoch 5/200  loss=0.6421
# [Pretrain] Epoch 10/200  loss=0.6314
# [Pretrain] Epoch 15/200  loss=0.6310
# [Pretrain] Epoch 20/200  loss=0.6311
# [Pretrain] Epoch 25/200  loss=0.6278
# [Pretrain] Epoch 30/200  loss=0.6270
# [Pretrain] Epoch 35/200  loss=0.6208
# [Pretrain] Epoch 40/200  loss=0.6260
# [Pretrain] Epoch 45/200  loss=0.6192
# [Pretrain] Epoch 50/200  loss=0.6209
# [Pretrain] Epoch 55/200  loss=0.6171
# [Pretrain] Epoch 60/200  loss=0.6187
# [Pretrain] Epoch 65/200  loss=0.6245
# [Pretrain] Epoch 70/200  loss=0.6195
# [Pretrain] Epoch 75/200  loss=0.6127
# [Pretrain] Epoch 80/200  loss=0.6109
# [Pretrain] Epoch 85/200  loss=0.6202
# [Pretrain] Epoch 90/200  loss=0.6065
# [Pretrain] Epoch 95/200  loss=0.6064
# [Pretrain] Epoch 100/200  loss=0.6187
# [Pretrain] Epoch 105/200  loss=0.6048
# [Pretrain] Epoch 110/200  loss=0.6052
# [Pretrain] Epoch 115/200  loss=0.6022
# [Pretrain] Epoch 120/200  loss=0.6110
# [Pretrain] Epoch 125/200  loss=0.6004
# [Pretrain] Epoch 130/200  loss=0.5973
# [Pretrain] Epoch 135/200  loss=0.5969
# [Pretrain] Epoch 140/200  loss=0.6037
# [Pretrain] Epoch 145/200  loss=0.6051
# [Pretrain] Epoch 150/200  loss=0.5997
# [Pretrain] Epoch 155/200  loss=0.5949
# [Pretrain] Epoch 160/200  loss=0.5954
# [Pretrain] Epoch 165/200  loss=0.5992
# [Pretrain] Epoch 170/200  loss=0.5921
# [Pretrain] Epoch 175/200  loss=0.5927
# [Pretrain] Epoch 180/200  loss=0.5903
# [Pretrain] Epoch 185/200  loss=0.6097
# [Pretrain] Epoch 190/200  loss=0.5953
# [Pretrain] Epoch 195/200  loss=0.6010
# [Pretrain] Epoch 200/200  loss=0.5913
# Source-only pretraining done.

# %%
# ----------------------------
# 4a) OT-based adaptation with GW ground cost + GW-barycentric mapping
# ----------------------------
# Requirements: pip install POT networkx
import numpy as np
import networkx as nx
import ot  # Python Optimal Transport (POT)

GW_REG = None        # regularization for inner GW (None = classic GW)
SINKHORN_REG = 0.01   # entropic reg for outer OT over graphs
TOPK = 5             # for per-source barycentric mapping, use top-k targets by OT weights
BARY_NITERS = 40     # iterations for GW barycenter solver
KNN_K = 4            # edges per node when rebuilding graph from barycenter distances
INF_DIST = 1e6

def pyg_to_distmat(data):
    """Compute an all-pairs shortest-path distance matrix from a PyG Data graph."""
    g = nx.Graph()
    num_nodes = data.num_nodes
    g.add_nodes_from(range(num_nodes))
    # unweighted SSSP on existing edges
    ei = data.edge_index.cpu().numpy()
    for u, v in ei.T:
        if u != v:
            g.add_edge(int(u), int(v), weight=1.0)
    # ensure connectivity by adding very large distances where unreachable
    dist = np.full((num_nodes, num_nodes), INF_DIST, dtype=np.float64)
    np.fill_diagonal(dist, 0.0)
    lengths = dict(nx.all_pairs_shortest_path_length(g))
    for i, row in lengths.items():
        for j, d in row.items():
            dist[int(i), int(j)] = float(d)
    # symmetrize just in case
    dist = 0.5 * (dist + dist.T)
    return dist

def uniform_weights(n):
    w = np.full(n, 1.0 / n, dtype=np.float64)
    return w

# Precompute intra-graph distance matrices and node weights
src_Cs, src_as = [], []
for d in src_train:
    src_Cs.append(pyg_to_distmat(d))
    src_as.append(uniform_weights(d.num_nodes))

tgt_Cs, tgt_as = [], []
for d in tgt_train:
    tgt_Cs.append(pyg_to_distmat(d))
    tgt_as.append(uniform_weights(d.num_nodes))

# Pairwise GW^2 cost between graphs (outer ground cost)
ns, nt = len(src_train), len(tgt_train)
outer_cost = np.zeros((ns, nt), dtype=np.float64)
for i in range(ns):
    C1, a1 = src_Cs[i], src_as[i]
    for j in range(nt):
        print("inner ot ", (float(i*nt) + j) / float(nt * ns))
        C2, a2 = tgt_Cs[j], tgt_as[j]
        # squared GW loss
        # outer_cost[i, j] = ot.gromov.entropic_gromov_wasserstein2(C1, C2, a1, a2, 'square_loss', epsilon=0.1, max_iter=100, tol=1e-7)
        outer_cost[i, j] = ot.gromov.gromov_wasserstein2(
            C1, C2, a1, a2, 'square_loss', log=False, armijo=False, max_iter=100, tol=1e-7
        )

# Outer OT coupling between source-graphs and target-graphs (uniform masses)
mu = uniform_weights(ns)
nu = uniform_weights(nt)
# entropic OT on the outer ground cost to get a soft plan
T_outer = ot.sinkhorn(mu, nu, outer_cost, reg=SINKHORN_REG)

# --- Barycentric mapping: per source graph i, build a GW-barycenter of top-k target graphs
def knn_graph_from_dist(C, k=KNN_K):
    """Return undirected edge index from a distance matrix using symmetric kNN."""
    n = C.shape[0]
    # for each node, pick k smallest (excluding self)
    neigh = np.argsort(C + np.eye(n) * INF_DIST, axis=1)[:, :k]
    edges = set()
    for i in range(n):
        for j in neigh[i]:
            if i != j:
                a, b = (int(i), int(j))
                if a > b: a, b = b, a
                edges.add((a, b))
    # ensure symmetry
    edge_index = np.array(list(edges), dtype=np.int64).T
    if edge_index.size == 0:
        edge_index = np.zeros((2,0), dtype=np.int64)
    return edge_index

def degree_onehot(edge_index, num_nodes, max_degree=OH_DEGREE):
    deg = np.zeros((num_nodes,), dtype=np.int64)
    if edge_index.size > 0:
        for u, v in edge_index.T:
            deg[u] += 1
            deg[v] += 1
    deg = np.minimum(deg, max_degree)  # cap
    x = np.zeros((num_nodes, max_degree + 1), dtype=np.float32)
    x[np.arange(num_nodes), deg] = 1.0
    return torch.from_numpy(x)

from torch_geometric.data import Data

transported_src = []
for i, d_src in enumerate(src_train):
    print(float(i) / len(src_train))
    w = T_outer[i]  # weights over target graphs
    if w.sum() <= 0:
        transported_src.append(d_src)  # fallback
        continue
    # pick top-k targets for efficiency
    top_idx = np.argsort(-w)[:TOPK]
    lambdas = w[top_idx]
    lambdas = lambdas / lambdas.sum()

    # assemble inputs for GW barycenter
    Cs = [tgt_Cs[j] for j in top_idx]
    ps = [tgt_as[j] for j in top_idx]
    # choose barycenter node count = source node count (keeps labels aligned)
    nb = d_src.num_nodes

    Cb = ot.gromov.gromov_barycenters(
        N=nb,
        Cs=Cs,
        ps=ps,
        p=np.full(nb, 1.0 / nb, dtype=np.float64),  # barycenter node weights (|p| = nb)
        lambdas=lambdas,
        loss_fun='square_loss',
        max_iter=BARY_NITERS,
        tol=1e-6,
        verbose=False,
        random_state=0,
    )
    # rebuild an unweighted symmetric kNN graph from the barycenter distance matrix
    ei = knn_graph_from_dist(Cb, k=KNN_K)
    # build node features as degree one-hot (consistent with OneHotDegree(..., cat=False))
    x_b = degree_onehot(ei, nb, max_degree=OH_DEGREE)
    # label stays the same as the source graph label
    y_b = d_src.y.clone()
    data_b = Data(x=x_b.to(DEVICE), edge_index=torch.from_numpy(ei).long().to(DEVICE), y=y_b.to(DEVICE))
    transported_src.append(data_b)

# Fine-tune the classifier on transported source graphs, then evaluate on target test set
trans_loader = DataLoader(transported_src, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# inner ot  0.0
# inner ot  2.5e-05
# inner ot  5e-05
# inner ot  7.5e-05
# inner ot  0.0001
# inner ot  0.000125
# inner ot  0.00015
# inner ot  0.000175
# inner ot  0.0002
# inner ot  0.000225
# inner ot  0.00025
# inner ot  0.000275
# inner ot  0.0003
# inner ot  0.000325
# inner ot  0.00035
# inner ot  0.000375
# inner ot  0.0004
# inner ot  0.000425
# inner ot  0.00045
# inner ot  0.000475
# inner ot  0.0005
# inner ot  0.000525
# inner ot  0.00055
# inner ot  0.000575
# inner ot  0.0006
# inner ot  0.000625
# inner ot  0.00065
# inner ot  0.000675
# inner ot  0.0007
# inner ot  0.000725
# inner ot  0.00075
# inner ot  0.000775
# inner ot  0.0008
# inner ot  0.000825
# inner ot  0.00085
# inner ot  0.000875
# inner ot  0.0009
# inner ot  0.000925
# inner ot  0.00095
# inner ot  0.000975
# inner ot  0.001
# inner ot  0.001025
# inner ot  0.00105
# inner ot  0.001075
# inner ot  0.0011
# inner ot  0.001125
# inner ot  0.00115
# inner ot  0.001175
# inner ot  0.0012
# inner ot  0.001225
# inner ot  0.00125
# inner ot  0.001275
# inner ot  0.0013
# inner ot  0.001325
# inner ot  0.00135
# inner ot  0.001375
# inner ot  0.0014
# inner ot  0.001425
# inner ot  0.00145
# inner ot  0.001475
# inner ot  0.0015
# inner ot  0.001525
# inner ot  0.00155
# inner ot  0.001575
# inner ot  0.0016
# inner ot  0.001625
# inner ot  0.00165
# inner ot  0.001675
# inner ot  0.0017
# inner ot  0.001725
# inner ot  0.00175
# inner ot  0.001775
# inner ot  0.0018
# inner ot  0.001825
# inner ot  0.00185
# inner ot  0.001875
# inner ot  0.0019
# inner ot  0.001925
# inner ot  0.00195
# inner ot  0.001975
# inner ot  0.002
# inner ot  0.002025
# inner ot  0.00205
# inner ot  0.002075
# inner ot  0.0021
# inner ot  0.002125
# inner ot  0.00215
# inner ot  0.002175
# inner ot  0.0022
# inner ot  0.002225
# inner ot  0.00225
# inner ot  0.002275
# inner ot  0.0023
# inner ot  0.002325
# inner ot  0.00235
# inner ot  0.002375
# inner ot  0.0024
# inner ot  0.002425
# inner ot  0.00245
# inner ot  0.002475
# inner ot  0.0025
# inner ot  0.002525
# inner ot  0.00255
# inner ot  0.002575
# inner ot  0.0026
# inner ot  0.002625
# inner ot  0.00265
# inner ot  0.002675
# inner ot  0.0027
# inner ot  0.002725
# inner ot  0.00275
# inner ot  0.002775
# inner ot  0.0028
# inner ot  0.002825
# inner ot  0.00285
# inner ot  0.002875
# inner ot  0.0029
# inner ot  0.002925
# inner ot  0.00295
# inner ot  0.002975
# inner ot  0.003
# inner ot  0.003025
# inner ot  0.00305
# inner ot  0.003075
# inner ot  0.0031
# inner ot  0.003125
# inner ot  0.00315
# inner ot  0.003175
# inner ot  0.0032
# inner ot  0.003225
# inner ot  0.00325
# inner ot  0.003275
# inner ot  0.0033
# inner ot  0.003325
# inner ot  0.00335
# inner ot  0.003375
# inner ot  0.0034
# inner ot  0.003425
# inner ot  0.00345
# inner ot  0.003475
# inner ot  0.0035
# inner ot  0.003525
# inner ot  0.00355
# inner ot  0.003575
# inner ot  0.0036
# inner ot  0.003625
# inner ot  0.00365
# inner ot  0.003675
# inner ot  0.0037
# inner ot  0.003725
# inner ot  0.00375
# inner ot  0.003775
# inner ot  0.0038
# inner ot  0.003825
# inner ot  0.00385
# inner ot  0.003875
# inner ot  0.0039
# inner ot  0.003925
# inner ot  0.00395
# inner ot  0.003975
# inner ot  0.004
# inner ot  0.004025
# inner ot  0.00405
# inner ot  0.004075
# inner ot  0.0041
# inner ot  0.004125
# inner ot  0.00415
# inner ot  0.004175
# inner ot  0.0042
# inner ot  0.004225
# inner ot  0.00425
# inner ot  0.004275
# inner ot  0.0043
# inner ot  0.004325
# inner ot  0.00435
# inner ot  0.004375
# inner ot  0.0044
# inner ot  0.004425
# inner ot  0.00445
# inner ot  0.004475
# inner ot  0.0045
# inner ot  0.004525
# inner ot  0.00455
# inner ot  0.004575
# inner ot  0.0046
# inner ot  0.004625
# inner ot  0.00465
# inner ot  0.004675
# inner ot  0.0047
# inner ot  0.004725
# inner ot  0.00475
# inner ot  0.004775
# inner ot  0.0048
# inner ot  0.004825
# inner ot  0.00485
# inner ot  0.004875
# inner ot  0.0049
# inner ot  0.004925
# inner ot  0.00495
# inner ot  0.004975
# inner ot  0.005
# inner ot  0.005025
# inner ot  0.00505
# inner ot  0.005075
# inner ot  0.0051
# inner ot  0.005125
# inner ot  0.00515
# inner ot  0.005175
# inner ot  0.0052
# inner ot  0.005225
# inner ot  0.00525
# inner ot  0.005275
# inner ot  0.0053
# inner ot  0.005325
# inner ot  0.00535
# inner ot  0.005375
# inner ot  0.0054
# inner ot  0.005425
# inner ot  0.00545
# inner ot  0.005475
# inner ot  0.0055
# inner ot  0.005525
# inner ot  0.00555
# inner ot  0.005575
# inner ot  0.0056
# inner ot  0.005625
# inner ot  0.00565
# inner ot  0.005675
# inner ot  0.0057
# inner ot  0.005725
# inner ot  0.00575
# inner ot  0.005775
# inner ot  0.0058
# inner ot  0.005825
# inner ot  0.00585
# inner ot  0.005875
# inner ot  0.0059
# inner ot  0.005925
# inner ot  0.00595
# inner ot  0.005975
# inner ot  0.006
# inner ot  0.006025
# inner ot  0.00605
# inner ot  0.006075
# inner ot  0.0061
# inner ot  0.006125
# inner ot  0.00615
# inner ot  0.006175
# inner ot  0.0062
# inner ot  0.006225
# inner ot  0.00625
# inner ot  0.006275
# inner ot  0.0063
# inner ot  0.006325
# inner ot  0.00635
# inner ot  0.006375
# inner ot  0.0064
# inner ot  0.006425
# inner ot  0.00645
# inner ot  0.006475
# inner ot  0.0065
# inner ot  0.006525
# inner ot  0.00655
# inner ot  0.006575
# inner ot  0.0066
# inner ot  0.006625
# inner ot  0.00665
# inner ot  0.006675
# inner ot  0.0067
# inner ot  0.006725
# inner ot  0.00675
# inner ot  0.006775
# inner ot  0.0068
# inner ot  0.006825
# inner ot  0.00685
# inner ot  0.006875
# inner ot  0.0069
# inner ot  0.006925
# inner ot  0.00695
# inner ot  0.006975
# inner ot  0.007
# inner ot  0.007025
# inner ot  0.00705
# inner ot  0.007075
# inner ot  0.0071
# inner ot  0.007125
# inner ot  0.00715
# inner ot  0.007175
# inner ot  0.0072
# inner ot  0.007225
# inner ot  0.00725
# inner ot  0.007275
# inner ot  0.0073
# inner ot  0.007325
# inner ot  0.00735
# inner ot  0.007375
# inner ot  0.0074
# inner ot  0.007425
# inner ot  0.00745
# inner ot  0.007475
# inner ot  0.0075
# inner ot  0.007525
# inner ot  0.00755
# inner ot  0.007575
# inner ot  0.0076
# inner ot  0.007625
# inner ot  0.00765
# inner ot  0.007675
# inner ot  0.0077
# inner ot  0.007725
# inner ot  0.00775
# inner ot  0.007775
# inner ot  0.0078
# inner ot  0.007825
# inner ot  0.00785
# inner ot  0.007875
# inner ot  0.0079
# inner ot  0.007925
# inner ot  0.00795
# inner ot  0.007975
# inner ot  0.008
# inner ot  0.008025
# inner ot  0.00805
# inner ot  0.008075
# inner ot  0.0081
# inner ot  0.008125
# inner ot  0.00815
# inner ot  0.008175
# inner ot  0.0082
# inner ot  0.008225
# inner ot  0.00825
# inner ot  0.008275
# inner ot  0.0083
# inner ot  0.008325
# inner ot  0.00835
# inner ot  0.008375
# inner ot  0.0084
# inner ot  0.008425
# inner ot  0.00845
# inner ot  0.008475
# inner ot  0.0085
# inner ot  0.008525
# inner ot  0.00855
# inner ot  0.008575
# inner ot  0.0086
# inner ot  0.008625
# inner ot  0.00865
# inner ot  0.008675
# inner ot  0.0087
# inner ot  0.008725
# inner ot  0.00875
# inner ot  0.008775
# inner ot  0.0088
# inner ot  0.008825
# inner ot  0.00885
# inner ot  0.008875
# inner ot  0.0089
# inner ot  0.008925
# inner ot  0.00895
# inner ot  0.008975
# inner ot  0.009
# inner ot  0.009025
# inner ot  0.00905
# inner ot  0.009075
# inner ot  0.0091
# inner ot  0.009125
# inner ot  0.00915
# inner ot  0.009175
# inner ot  0.0092
# inner ot  0.009225
# inner ot  0.00925
# inner ot  0.009275
# inner ot  0.0093
# inner ot  0.009325
# inner ot  0.00935
# inner ot  0.009375
# inner ot  0.0094
# inner ot  0.009425
# inner ot  0.00945
# inner ot  0.009475
# inner ot  0.0095
# inner ot  0.009525
# inner ot  0.00955
# inner ot  0.009575
# inner ot  0.0096
# inner ot  0.009625
# inner ot  0.00965
# inner ot  0.009675
# inner ot  0.0097
# inner ot  0.009725
# inner ot  0.00975
# inner ot  0.009775
# inner ot  0.0098
# inner ot  0.009825
# inner ot  0.00985
# inner ot  0.009875
# inner ot  0.0099
# inner ot  0.009925
# inner ot  0.00995
# inner ot  0.009975
# inner ot  0.01
# inner ot  0.010025
# inner ot  0.01005
# inner ot  0.010075
# inner ot  0.0101
# inner ot  0.010125
# inner ot  0.01015
# inner ot  0.010175
# inner ot  0.0102
# inner ot  0.010225
# inner ot  0.01025
# inner ot  0.010275
# inner ot  0.0103
# inner ot  0.010325
# inner ot  0.01035
# inner ot  0.010375
# inner ot  0.0104
# inner ot  0.010425
# inner ot  0.01045
# inner ot  0.010475
# inner ot  0.0105
# inner ot  0.010525
# inner ot  0.01055
# inner ot  0.010575
# inner ot  0.0106
# inner ot  0.010625
# inner ot  0.01065
# inner ot  0.010675
# inner ot  0.0107
# inner ot  0.010725
# inner ot  0.01075
# inner ot  0.010775
# inner ot  0.0108
# inner ot  0.010825
# inner ot  0.01085
# inner ot  0.010875
# inner ot  0.0109
# inner ot  0.010925
# inner ot  0.01095
# inner ot  0.010975
# inner ot  0.011
# inner ot  0.011025
# inner ot  0.01105
# inner ot  0.011075
# inner ot  0.0111
# inner ot  0.011125
# inner ot  0.01115
# inner ot  0.011175
# inner ot  0.0112
# inner ot  0.011225
# inner ot  0.01125
# inner ot  0.011275
# inner ot  0.0113
# inner ot  0.011325
# inner ot  0.01135
# inner ot  0.011375
# inner ot  0.0114
# inner ot  0.011425
# inner ot  0.01145
# inner ot  0.011475
# inner ot  0.0115
# inner ot  0.011525
# inner ot  0.01155
# inner ot  0.011575
# inner ot  0.0116
# inner ot  0.011625
# inner ot  0.01165
# inner ot  0.011675
# inner ot  0.0117
# inner ot  0.011725
# inner ot  0.01175
# inner ot  0.011775
# inner ot  0.0118
# inner ot  0.011825
# inner ot  0.01185
# inner ot  0.011875
# inner ot  0.0119
# inner ot  0.011925
# inner ot  0.01195
# inner ot  0.011975
# inner ot  0.012
# inner ot  0.012025
# inner ot  0.01205
# inner ot  0.012075
# inner ot  0.0121
# inner ot  0.012125
# inner ot  0.01215
# inner ot  0.012175
# inner ot  0.0122
# inner ot  0.012225
# inner ot  0.01225
# inner ot  0.012275
# inner ot  0.0123
# inner ot  0.012325
# inner ot  0.01235
# inner ot  0.012375
# inner ot  0.0124
# inner ot  0.012425
# inner ot  0.01245
# inner ot  0.012475
# inner ot  0.0125
# inner ot  0.012525
# inner ot  0.01255
# inner ot  0.012575
# inner ot  0.0126
# inner ot  0.012625
# inner ot  0.01265
# inner ot  0.012675
# inner ot  0.0127
# inner ot  0.012725
# inner ot  0.01275
# inner ot  0.012775
# inner ot  0.0128
# inner ot  0.012825
# inner ot  0.01285
# inner ot  0.012875
# inner ot  0.0129
# inner ot  0.012925
# inner ot  0.01295
# inner ot  0.012975
# inner ot  0.013
# inner ot  0.013025
# inner ot  0.01305
# inner ot  0.013075
# inner ot  0.0131
# inner ot  0.013125
# inner ot  0.01315
# inner ot  0.013175
# inner ot  0.0132
# inner ot  0.013225
# inner ot  0.01325
# inner ot  0.013275
# inner ot  0.0133
# inner ot  0.013325
# inner ot  0.01335
# inner ot  0.013375
# inner ot  0.0134
# inner ot  0.013425
# inner ot  0.01345
# inner ot  0.013475
# inner ot  0.0135
# inner ot  0.013525
# inner ot  0.01355
# inner ot  0.013575
# inner ot  0.0136
# inner ot  0.013625
# inner ot  0.01365
# inner ot  0.013675
# inner ot  0.0137
# inner ot  0.013725
# inner ot  0.01375
# inner ot  0.013775
# inner ot  0.0138
# inner ot  0.013825
# inner ot  0.01385
# inner ot  0.013875
# inner ot  0.0139
# inner ot  0.013925
# inner ot  0.01395
# inner ot  0.013975
# inner ot  0.014
# inner ot  0.014025
# inner ot  0.01405
# inner ot  0.014075
# inner ot  0.0141
# inner ot  0.014125
# inner ot  0.01415
# inner ot  0.014175
# inner ot  0.0142
# inner ot  0.014225
# inner ot  0.01425
# inner ot  0.014275
# inner ot  0.0143
# inner ot  0.014325
# inner ot  0.01435
# inner ot  0.014375
# inner ot  0.0144
# inner ot  0.014425
# inner ot  0.01445
# inner ot  0.014475
# inner ot  0.0145
# inner ot  0.014525
# inner ot  0.01455
# inner ot  0.014575
# inner ot  0.0146
# inner ot  0.014625
# inner ot  0.01465
# inner ot  0.014675
# inner ot  0.0147
# inner ot  0.014725
# inner ot  0.01475
# inner ot  0.014775
# inner ot  0.0148
# inner ot  0.014825
# inner ot  0.01485
# inner ot  0.014875
# inner ot  0.0149
# inner ot  0.014925
# inner ot  0.01495
# inner ot  0.014975
# inner ot  0.015
# inner ot  0.015025
# inner ot  0.01505
# inner ot  0.015075
# inner ot  0.0151
# inner ot  0.015125
# inner ot  0.01515
# inner ot  0.015175
# inner ot  0.0152
# inner ot  0.015225
# inner ot  0.01525
# inner ot  0.015275
# inner ot  0.0153
# inner ot  0.015325
# inner ot  0.01535
# inner ot  0.015375
# inner ot  0.0154
# inner ot  0.015425
# inner ot  0.01545
# inner ot  0.015475
# inner ot  0.0155
# inner ot  0.015525
# inner ot  0.01555
# inner ot  0.015575
# inner ot  0.0156
# inner ot  0.015625
# inner ot  0.01565
# inner ot  0.015675
# inner ot  0.0157
# inner ot  0.015725
# inner ot  0.01575
# inner ot  0.015775
# inner ot  0.0158
# inner ot  0.015825
# inner ot  0.01585
# inner ot  0.015875
# inner ot  0.0159
# inner ot  0.015925
# inner ot  0.01595
# inner ot  0.015975
# inner ot  0.016
# inner ot  0.016025
# inner ot  0.01605
# inner ot  0.016075
# inner ot  0.0161
# inner ot  0.016125
# inner ot  0.01615
# inner ot  0.016175
# inner ot  0.0162
# inner ot  0.016225
# inner ot  0.01625
# inner ot  0.016275
# inner ot  0.0163
# inner ot  0.016325
# inner ot  0.01635
# inner ot  0.016375
# inner ot  0.0164
# inner ot  0.016425
# inner ot  0.01645
# inner ot  0.016475
# inner ot  0.0165
# inner ot  0.016525
# inner ot  0.01655
# inner ot  0.016575
# inner ot  0.0166
# inner ot  0.016625
# inner ot  0.01665
# inner ot  0.016675
# inner ot  0.0167
# inner ot  0.016725
# inner ot  0.01675
# inner ot  0.016775
# inner ot  0.0168
# inner ot  0.016825
# inner ot  0.01685
# inner ot  0.016875
# inner ot  0.0169
# inner ot  0.016925
# inner ot  0.01695
# inner ot  0.016975
# inner ot  0.017
# inner ot  0.017025
# inner ot  0.01705
# inner ot  0.017075
# inner ot  0.0171
# inner ot  0.017125
# inner ot  0.01715
# inner ot  0.017175
# inner ot  0.0172
# inner ot  0.017225
# inner ot  0.01725
# inner ot  0.017275
# inner ot  0.0173
# inner ot  0.017325
# inner ot  0.01735
# inner ot  0.017375
# inner ot  0.0174
# inner ot  0.017425
# inner ot  0.01745
# inner ot  0.017475
# inner ot  0.0175
# inner ot  0.017525
# inner ot  0.01755
# inner ot  0.017575
# inner ot  0.0176
# inner ot  0.017625
# inner ot  0.01765
# inner ot  0.017675
# inner ot  0.0177
# inner ot  0.017725
# inner ot  0.01775
# inner ot  0.017775
# inner ot  0.0178
# inner ot  0.017825
# inner ot  0.01785
# inner ot  0.017875
# inner ot  0.0179
# inner ot  0.017925
# inner ot  0.01795
# inner ot  0.017975
# inner ot  0.018
# inner ot  0.018025
# inner ot  0.01805
# inner ot  0.018075
# inner ot  0.0181
# inner ot  0.018125
# inner ot  0.01815
# inner ot  0.018175
# inner ot  0.0182
# inner ot  0.018225
# inner ot  0.01825
# inner ot  0.018275
# inner ot  0.0183
# inner ot  0.018325
# inner ot  0.01835
# inner ot  0.018375
# inner ot  0.0184
# inner ot  0.018425
# inner ot  0.01845
# inner ot  0.018475
# inner ot  0.0185
# inner ot  0.018525
# inner ot  0.01855
# inner ot  0.018575
# inner ot  0.0186
# inner ot  0.018625
# inner ot  0.01865
# inner ot  0.018675
# inner ot  0.0187
# inner ot  0.018725
# inner ot  0.01875
# inner ot  0.018775
# inner ot  0.0188
# inner ot  0.018825
# inner ot  0.01885
# inner ot  0.018875
# inner ot  0.0189
# inner ot  0.018925
# inner ot  0.01895
# inner ot  0.018975
# inner ot  0.019
# inner ot  0.019025
# inner ot  0.01905
# inner ot  0.019075
# inner ot  0.0191
# inner ot  0.019125
# inner ot  0.01915
# inner ot  0.019175
# inner ot  0.0192
# inner ot  0.019225
# inner ot  0.01925
# inner ot  0.019275
# inner ot  0.0193
# inner ot  0.019325
# inner ot  0.01935
# inner ot  0.019375
# inner ot  0.0194
# inner ot  0.019425
# inner ot  0.01945
# inner ot  0.019475
# inner ot  0.0195
# inner ot  0.019525
# inner ot  0.01955
# inner ot  0.019575
# inner ot  0.0196
# inner ot  0.019625
# inner ot  0.01965
# inner ot  0.019675
# inner ot  0.0197
# inner ot  0.019725
# inner ot  0.01975
# inner ot  0.019775
# inner ot  0.0198
# inner ot  0.019825
# inner ot  0.01985
# inner ot  0.019875
# inner ot  0.0199
# inner ot  0.019925
# inner ot  0.01995
# inner ot  0.019975
# inner ot  0.02
# inner ot  0.020025
# inner ot  0.02005
# inner ot  0.020075
# inner ot  0.0201
# inner ot  0.020125
# inner ot  0.02015
# inner ot  0.020175
# inner ot  0.0202
# inner ot  0.020225
# inner ot  0.02025
# inner ot  0.020275
# inner ot  0.0203
# inner ot  0.020325
# inner ot  0.02035
# inner ot  0.020375
# inner ot  0.0204
# inner ot  0.020425
# inner ot  0.02045
# inner ot  0.020475
# inner ot  0.0205
# inner ot  0.020525
# inner ot  0.02055
# inner ot  0.020575
# inner ot  0.0206
# inner ot  0.020625
# inner ot  0.02065
# inner ot  0.020675
# inner ot  0.0207
# inner ot  0.020725
# inner ot  0.02075
# inner ot  0.020775
# inner ot  0.0208
# inner ot  0.020825
# inner ot  0.02085
# inner ot  0.020875
# inner ot  0.0209
# inner ot  0.020925
# inner ot  0.02095
# inner ot  0.020975
# inner ot  0.021
# inner ot  0.021025
# inner ot  0.02105
# inner ot  0.021075
# inner ot  0.0211
# inner ot  0.021125
# inner ot  0.02115
# inner ot  0.021175
# inner ot  0.0212
# inner ot  0.021225
# inner ot  0.02125
# inner ot  0.021275
# inner ot  0.0213
# inner ot  0.021325
# inner ot  0.02135
# inner ot  0.021375
# inner ot  0.0214
# inner ot  0.021425
# inner ot  0.02145
# inner ot  0.021475
# inner ot  0.0215
# inner ot  0.021525
# inner ot  0.02155
# inner ot  0.021575
# inner ot  0.0216
# inner ot  0.021625
# inner ot  0.02165
# inner ot  0.021675
# inner ot  0.0217
# inner ot  0.021725
# inner ot  0.02175
# inner ot  0.021775
# inner ot  0.0218
# inner ot  0.021825
# inner ot  0.02185
# inner ot  0.021875
# inner ot  0.0219
# inner ot  0.021925
# inner ot  0.02195
# inner ot  0.021975
# inner ot  0.022
# inner ot  0.022025
# inner ot  0.02205
# inner ot  0.022075
# inner ot  0.0221
# inner ot  0.022125
# inner ot  0.02215
# inner ot  0.022175
# inner ot  0.0222
# inner ot  0.022225
# inner ot  0.02225
# inner ot  0.022275
# inner ot  0.0223
# inner ot  0.022325
# inner ot  0.02235
# inner ot  0.022375
# inner ot  0.0224
# inner ot  0.022425
# inner ot  0.02245
# inner ot  0.022475
# inner ot  0.0225
# inner ot  0.022525
# inner ot  0.02255
# inner ot  0.022575
# inner ot  0.0226
# inner ot  0.022625
# inner ot  0.02265
# inner ot  0.022675
# inner ot  0.0227
# inner ot  0.022725
# inner ot  0.02275
# inner ot  0.022775
# inner ot  0.0228
# inner ot  0.022825
# inner ot  0.02285
# inner ot  0.022875
# inner ot  0.0229
# inner ot  0.022925
# inner ot  0.02295
# inner ot  0.022975
# inner ot  0.023
# inner ot  0.023025
# inner ot  0.02305
# inner ot  0.023075
# inner ot  0.0231
# inner ot  0.023125
# inner ot  0.02315
# inner ot  0.023175
# inner ot  0.0232
# inner ot  0.023225
# inner ot  0.02325
# inner ot  0.023275
# inner ot  0.0233
# inner ot  0.023325
# inner ot  0.02335
# inner ot  0.023375
# inner ot  0.0234
# inner ot  0.023425
# inner ot  0.02345
# inner ot  0.023475
# inner ot  0.0235
# inner ot  0.023525
# inner ot  0.02355
# inner ot  0.023575
# inner ot  0.0236
# inner ot  0.023625
# inner ot  0.02365
# inner ot  0.023675
# inner ot  0.0237
# inner ot  0.023725
# inner ot  0.02375
# inner ot  0.023775
# inner ot  0.0238
# inner ot  0.023825
# inner ot  0.02385
# inner ot  0.023875
# inner ot  0.0239
# inner ot  0.023925
# inner ot  0.02395
# inner ot  0.023975
# inner ot  0.024
# inner ot  0.024025
# inner ot  0.02405
# inner ot  0.024075
# inner ot  0.0241
# inner ot  0.024125
# inner ot  0.02415
# inner ot  0.024175
# inner ot  0.0242
# inner ot  0.024225
# inner ot  0.02425
# inner ot  0.024275
# inner ot  0.0243
# inner ot  0.024325
# inner ot  0.02435
# inner ot  0.024375
# inner ot  0.0244
# inner ot  0.024425
# inner ot  0.02445
# inner ot  0.024475
# inner ot  0.0245
# inner ot  0.024525
# inner ot  0.02455
# inner ot  0.024575
# inner ot  0.0246
# inner ot  0.024625
# inner ot  0.02465
# inner ot  0.024675
# inner ot  0.0247
# inner ot  0.024725
# inner ot  0.02475
# inner ot  0.024775
# inner ot  0.0248
# inner ot  0.024825
# inner ot  0.02485
# inner ot  0.024875
# inner ot  0.0249
# inner ot  0.024925
# inner ot  0.02495
# inner ot  0.024975
# inner ot  0.025
# inner ot  0.025025
# inner ot  0.02505
# inner ot  0.025075
# inner ot  0.0251
# inner ot  0.025125
# inner ot  0.02515
# inner ot  0.025175
# inner ot  0.0252
# inner ot  0.025225
# inner ot  0.02525
# inner ot  0.025275
# inner ot  0.0253
# inner ot  0.025325
# inner ot  0.02535
# inner ot  0.025375
# inner ot  0.0254
# inner ot  0.025425
# inner ot  0.02545
# inner ot  0.025475
# inner ot  0.0255
# inner ot  0.025525
# inner ot  0.02555
# inner ot  0.025575
# inner ot  0.0256
# inner ot  0.025625
# inner ot  0.02565
# inner ot  0.025675
# inner ot  0.0257
# inner ot  0.025725
# inner ot  0.02575
# inner ot  0.025775
# inner ot  0.0258
# inner ot  0.025825
# inner ot  0.02585
# inner ot  0.025875
# inner ot  0.0259
# inner ot  0.025925
# inner ot  0.02595
# inner ot  0.025975
# inner ot  0.026
# inner ot  0.026025
# inner ot  0.02605
# inner ot  0.026075
# inner ot  0.0261
# inner ot  0.026125
# inner ot  0.02615
# inner ot  0.026175
# inner ot  0.0262
# inner ot  0.026225
# inner ot  0.02625
# inner ot  0.026275
# inner ot  0.0263
# inner ot  0.026325
# inner ot  0.02635
# inner ot  0.026375
# inner ot  0.0264
# inner ot  0.026425
# inner ot  0.02645
# inner ot  0.026475
# inner ot  0.0265
# inner ot  0.026525
# inner ot  0.02655
# inner ot  0.026575
# inner ot  0.0266
# inner ot  0.026625
# inner ot  0.02665
# inner ot  0.026675
# inner ot  0.0267
# inner ot  0.026725
# inner ot  0.02675
# inner ot  0.026775
# inner ot  0.0268
# inner ot  0.026825
# inner ot  0.02685
# inner ot  0.026875
# inner ot  0.0269
# inner ot  0.026925
# inner ot  0.02695
# inner ot  0.026975
# inner ot  0.027
# inner ot  0.027025
# inner ot  0.02705
# inner ot  0.027075
# inner ot  0.0271
# inner ot  0.027125
# inner ot  0.02715
# inner ot  0.027175
# inner ot  0.0272
# inner ot  0.027225
# inner ot  0.02725
# inner ot  0.027275
# inner ot  0.0273
# inner ot  0.027325
# inner ot  0.02735
# inner ot  0.027375
# inner ot  0.0274
# inner ot  0.027425
# inner ot  0.02745
# inner ot  0.027475
# inner ot  0.0275
# inner ot  0.027525
# inner ot  0.02755
# inner ot  0.027575
# inner ot  0.0276
# inner ot  0.027625
# inner ot  0.02765
# inner ot  0.027675
# inner ot  0.0277
# inner ot  0.027725
# inner ot  0.02775
# inner ot  0.027775
# inner ot  0.0278
# inner ot  0.027825
# inner ot  0.02785
# inner ot  0.027875
# inner ot  0.0279
# inner ot  0.027925
# inner ot  0.02795
# inner ot  0.027975
# inner ot  0.028
# inner ot  0.028025
# inner ot  0.02805
# inner ot  0.028075
# inner ot  0.0281
# inner ot  0.028125
# inner ot  0.02815
# inner ot  0.028175
# inner ot  0.0282
# inner ot  0.028225
# inner ot  0.02825
# inner ot  0.028275
# inner ot  0.0283
# inner ot  0.028325
# inner ot  0.02835
# inner ot  0.028375
# inner ot  0.0284
# inner ot  0.028425
# inner ot  0.02845
# inner ot  0.028475
# inner ot  0.0285
# inner ot  0.028525
# inner ot  0.02855
# inner ot  0.028575
# inner ot  0.0286
# inner ot  0.028625
# inner ot  0.02865
# inner ot  0.028675
# inner ot  0.0287
# inner ot  0.028725
# inner ot  0.02875
# inner ot  0.028775
# inner ot  0.0288
# inner ot  0.028825
# inner ot  0.02885
# inner ot  0.028875
# inner ot  0.0289
# inner ot  0.028925
# inner ot  0.02895
# inner ot  0.028975
# inner ot  0.029
# inner ot  0.029025
# inner ot  0.02905
# inner ot  0.029075
# inner ot  0.0291
# inner ot  0.029125
# inner ot  0.02915
# inner ot  0.029175
# inner ot  0.0292
# inner ot  0.029225
# inner ot  0.02925
# inner ot  0.029275
# inner ot  0.0293
# inner ot  0.029325
# inner ot  0.02935
# inner ot  0.029375
# inner ot  0.0294
# inner ot  0.029425
# inner ot  0.02945
# inner ot  0.029475
# inner ot  0.0295
# inner ot  0.029525
# inner ot  0.02955
# inner ot  0.029575
# inner ot  0.0296
# inner ot  0.029625
# inner ot  0.02965
# inner ot  0.029675
# inner ot  0.0297
# inner ot  0.029725
# inner ot  0.02975
# inner ot  0.029775
# inner ot  0.0298
# inner ot  0.029825
# inner ot  0.02985
# inner ot  0.029875
# inner ot  0.0299
# inner ot  0.029925
# inner ot  0.02995
# inner ot  0.029975
# inner ot  0.03
# inner ot  0.030025
# inner ot  0.03005
# inner ot  0.030075
# inner ot  0.0301
# inner ot  0.030125
# inner ot  0.03015
# inner ot  0.030175
# inner ot  0.0302
# inner ot  0.030225
# inner ot  0.03025
# inner ot  0.030275
# inner ot  0.0303
# inner ot  0.030325
# inner ot  0.03035
# inner ot  0.030375
# inner ot  0.0304
# inner ot  0.030425
# inner ot  0.03045
# inner ot  0.030475
# inner ot  0.0305
# inner ot  0.030525
# inner ot  0.03055
# inner ot  0.030575
# inner ot  0.0306
# inner ot  0.030625
# inner ot  0.03065
# inner ot  0.030675
# inner ot  0.0307
# inner ot  0.030725
# inner ot  0.03075
# inner ot  0.030775
# inner ot  0.0308
# inner ot  0.030825
# inner ot  0.03085
# inner ot  0.030875
# inner ot  0.0309
# inner ot  0.030925
# inner ot  0.03095
# inner ot  0.030975
# inner ot  0.031
# inner ot  0.031025
# inner ot  0.03105
# inner ot  0.031075
# inner ot  0.0311
# inner ot  0.031125
# inner ot  0.03115
# inner ot  0.031175
# inner ot  0.0312
# inner ot  0.031225
# inner ot  0.03125
# inner ot  0.031275
# inner ot  0.0313
# inner ot  0.031325
# inner ot  0.03135
# inner ot  0.031375
# inner ot  0.0314
# inner ot  0.031425
# inner ot  0.03145
# inner ot  0.031475
# inner ot  0.0315
# inner ot  0.031525
# inner ot  0.03155
# inner ot  0.031575
# inner ot  0.0316
# inner ot  0.031625
# inner ot  0.03165
# inner ot  0.031675
# inner ot  0.0317
# inner ot  0.031725
# inner ot  0.03175
# inner ot  0.031775
# inner ot  0.0318
# inner ot  0.031825
# inner ot  0.03185
# inner ot  0.031875
# inner ot  0.0319
# inner ot  0.031925
# inner ot  0.03195
# inner ot  0.031975
# inner ot  0.032
# inner ot  0.032025
# inner ot  0.03205
# inner ot  0.032075
# inner ot  0.0321
# inner ot  0.032125
# inner ot  0.03215
# inner ot  0.032175
# inner ot  0.0322
# inner ot  0.032225
# inner ot  0.03225
# inner ot  0.032275
# inner ot  0.0323
# inner ot  0.032325
# inner ot  0.03235
# inner ot  0.032375
# inner ot  0.0324
# inner ot  0.032425
# inner ot  0.03245
# inner ot  0.032475
# inner ot  0.0325
# inner ot  0.032525
# inner ot  0.03255
# inner ot  0.032575
# inner ot  0.0326
# inner ot  0.032625
# inner ot  0.03265
# inner ot  0.032675
# inner ot  0.0327
# inner ot  0.032725
# inner ot  0.03275
# inner ot  0.032775
# inner ot  0.0328
# inner ot  0.032825
# inner ot  0.03285
# inner ot  0.032875
# inner ot  0.0329
# inner ot  0.032925
# inner ot  0.03295
# inner ot  0.032975
# inner ot  0.033
# inner ot  0.033025
# inner ot  0.03305
# inner ot  0.033075
# inner ot  0.0331
# inner ot  0.033125
# inner ot  0.03315
# inner ot  0.033175
# inner ot  0.0332
# inner ot  0.033225
# inner ot  0.03325
# inner ot  0.033275
# inner ot  0.0333
# inner ot  0.033325
# inner ot  0.03335
# inner ot  0.033375
# inner ot  0.0334
# inner ot  0.033425
# inner ot  0.03345
# inner ot  0.033475
# inner ot  0.0335
# inner ot  0.033525
# inner ot  0.03355
# inner ot  0.033575
# inner ot  0.0336
# inner ot  0.033625
# inner ot  0.03365
# inner ot  0.033675
# inner ot  0.0337
# inner ot  0.033725
# inner ot  0.03375
# inner ot  0.033775
# inner ot  0.0338
# inner ot  0.033825
# inner ot  0.03385
# inner ot  0.033875
# inner ot  0.0339
# inner ot  0.033925
# inner ot  0.03395
# inner ot  0.033975
# inner ot  0.034
# inner ot  0.034025
# inner ot  0.03405
# inner ot  0.034075
# inner ot  0.0341
# inner ot  0.034125
# inner ot  0.03415
# inner ot  0.034175
# inner ot  0.0342
# inner ot  0.034225
# inner ot  0.03425
# inner ot  0.034275
# inner ot  0.0343
# inner ot  0.034325
# inner ot  0.03435
# inner ot  0.034375
# inner ot  0.0344
# inner ot  0.034425
# inner ot  0.03445
# inner ot  0.034475
# inner ot  0.0345
# inner ot  0.034525
# inner ot  0.03455
# inner ot  0.034575
# inner ot  0.0346
# inner ot  0.034625
# inner ot  0.03465
# inner ot  0.034675
# inner ot  0.0347
# inner ot  0.034725
# inner ot  0.03475
# inner ot  0.034775
# inner ot  0.0348
# inner ot  0.034825
# inner ot  0.03485
# inner ot  0.034875
# inner ot  0.0349
# inner ot  0.034925
# inner ot  0.03495
# inner ot  0.034975
# inner ot  0.035
# inner ot  0.035025
# inner ot  0.03505
# inner ot  0.035075
# inner ot  0.0351
# inner ot  0.035125
# inner ot  0.03515
# inner ot  0.035175
# inner ot  0.0352
# inner ot  0.035225
# inner ot  0.03525
# inner ot  0.035275
# inner ot  0.0353
# inner ot  0.035325
# inner ot  0.03535
# inner ot  0.035375
# inner ot  0.0354
# inner ot  0.035425
# inner ot  0.03545
# inner ot  0.035475
# inner ot  0.0355
# inner ot  0.035525
# inner ot  0.03555
# inner ot  0.035575
# inner ot  0.0356
# inner ot  0.035625
# inner ot  0.03565
# inner ot  0.035675
# inner ot  0.0357
# inner ot  0.035725
# inner ot  0.03575
# inner ot  0.035775
# inner ot  0.0358
# inner ot  0.035825
# inner ot  0.03585
# inner ot  0.035875
# inner ot  0.0359
# inner ot  0.035925
# inner ot  0.03595
# inner ot  0.035975
# inner ot  0.036
# inner ot  0.036025
# inner ot  0.03605
# inner ot  0.036075
# inner ot  0.0361
# inner ot  0.036125
# inner ot  0.03615
# inner ot  0.036175
# inner ot  0.0362
# inner ot  0.036225
# inner ot  0.03625
# inner ot  0.036275
# inner ot  0.0363
# inner ot  0.036325
# inner ot  0.03635
# inner ot  0.036375
# inner ot  0.0364
# inner ot  0.036425
# inner ot  0.03645
# inner ot  0.036475
# inner ot  0.0365
# inner ot  0.036525
# inner ot  0.03655
# inner ot  0.036575
# inner ot  0.0366
# inner ot  0.036625
# inner ot  0.03665
# inner ot  0.036675
# inner ot  0.0367
# inner ot  0.036725
# inner ot  0.03675
# inner ot  0.036775
# inner ot  0.0368
# inner ot  0.036825
# inner ot  0.03685
# inner ot  0.036875
# inner ot  0.0369
# inner ot  0.036925
# inner ot  0.03695
# inner ot  0.036975
# inner ot  0.037
# inner ot  0.037025
# inner ot  0.03705
# inner ot  0.037075
# inner ot  0.0371
# inner ot  0.037125
# inner ot  0.03715
# inner ot  0.037175
# inner ot  0.0372
# inner ot  0.037225
# inner ot  0.03725
# inner ot  0.037275
# inner ot  0.0373
# inner ot  0.037325
# inner ot  0.03735
# inner ot  0.037375
# inner ot  0.0374
# inner ot  0.037425
# inner ot  0.03745
# inner ot  0.037475
# inner ot  0.0375
# inner ot  0.037525
# inner ot  0.03755
# inner ot  0.037575
# inner ot  0.0376
# inner ot  0.037625
# inner ot  0.03765
# inner ot  0.037675
# inner ot  0.0377
# inner ot  0.037725
# inner ot  0.03775
# inner ot  0.037775
# inner ot  0.0378
# inner ot  0.037825
# inner ot  0.03785
# inner ot  0.037875
# inner ot  0.0379
# inner ot  0.037925
# inner ot  0.03795
# inner ot  0.037975
# inner ot  0.038
# inner ot  0.038025
# inner ot  0.03805
# inner ot  0.038075
# inner ot  0.0381
# inner ot  0.038125
# inner ot  0.03815
# inner ot  0.038175
# inner ot  0.0382
# inner ot  0.038225
# inner ot  0.03825
# inner ot  0.038275
# inner ot  0.0383
# inner ot  0.038325
# inner ot  0.03835
# inner ot  0.038375
# inner ot  0.0384
# inner ot  0.038425
# inner ot  0.03845
# inner ot  0.038475
# inner ot  0.0385
# inner ot  0.038525
# inner ot  0.03855
# inner ot  0.038575
# inner ot  0.0386
# inner ot  0.038625
# inner ot  0.03865
# inner ot  0.038675
# inner ot  0.0387
# inner ot  0.038725
# inner ot  0.03875
# inner ot  0.038775
# inner ot  0.0388
# inner ot  0.038825
# inner ot  0.03885
# inner ot  0.038875
# inner ot  0.0389
# inner ot  0.038925
# inner ot  0.03895
# inner ot  0.038975
# inner ot  0.039
# inner ot  0.039025
# inner ot  0.03905
# inner ot  0.039075
# inner ot  0.0391
# inner ot  0.039125
# inner ot  0.03915
# inner ot  0.039175
# inner ot  0.0392
# inner ot  0.039225
# inner ot  0.03925
# inner ot  0.039275
# inner ot  0.0393
# inner ot  0.039325
# inner ot  0.03935
# inner ot  0.039375
# inner ot  0.0394
# inner ot  0.039425
# inner ot  0.03945
# inner ot  0.039475
# inner ot  0.0395
# inner ot  0.039525
# inner ot  0.03955
# inner ot  0.039575
# inner ot  0.0396
# inner ot  0.039625
# inner ot  0.03965
# inner ot  0.039675
# inner ot  0.0397
# inner ot  0.039725
# inner ot  0.03975
# inner ot  0.039775
# inner ot  0.0398
# inner ot  0.039825
# inner ot  0.03985
# inner ot  0.039875
# inner ot  0.0399
# inner ot  0.039925
# inner ot  0.03995
# inner ot  0.039975
# inner ot  0.04
# inner ot  0.040025
# inner ot  0.04005
# inner ot  0.040075
# inner ot  0.0401
# inner ot  0.040125
# inner ot  0.04015
# inner ot  0.040175
# inner ot  0.0402
# inner ot  0.040225
# inner ot  0.04025
# inner ot  0.040275
# inner ot  0.0403
# inner ot  0.040325
# inner ot  0.04035
# inner ot  0.040375
# inner ot  0.0404
# inner ot  0.040425
# inner ot  0.04045
# inner ot  0.040475
# inner ot  0.0405
# inner ot  0.040525
# inner ot  0.04055
# inner ot  0.040575
# inner ot  0.0406
# inner ot  0.040625
# inner ot  0.04065
# inner ot  0.040675
# inner ot  0.0407
# inner ot  0.040725
# inner ot  0.04075
# inner ot  0.040775
# inner ot  0.0408
# inner ot  0.040825
# inner ot  0.04085
# inner ot  0.040875
# inner ot  0.0409
# inner ot  0.040925
# inner ot  0.04095
# inner ot  0.040975
# inner ot  0.041
# inner ot  0.041025
# inner ot  0.04105
# inner ot  0.041075
# inner ot  0.0411
# inner ot  0.041125
# inner ot  0.04115
# inner ot  0.041175
# inner ot  0.0412
# inner ot  0.041225
# inner ot  0.04125
# inner ot  0.041275
# inner ot  0.0413
# inner ot  0.041325
# inner ot  0.04135
# inner ot  0.041375
# inner ot  0.0414
# inner ot  0.041425
# inner ot  0.04145
# inner ot  0.041475
# inner ot  0.0415
# inner ot  0.041525
# inner ot  0.04155
# inner ot  0.041575
# inner ot  0.0416
# inner ot  0.041625
# inner ot  0.04165
# inner ot  0.041675
# inner ot  0.0417
# inner ot  0.041725
# inner ot  0.04175
# inner ot  0.041775
# inner ot  0.0418
# inner ot  0.041825
# inner ot  0.04185
# inner ot  0.041875
# inner ot  0.0419
# inner ot  0.041925
# inner ot  0.04195
# inner ot  0.041975
# inner ot  0.042
# inner ot  0.042025
# inner ot  0.04205
# inner ot  0.042075
# inner ot  0.0421
# inner ot  0.042125
# inner ot  0.04215
# inner ot  0.042175
# inner ot  0.0422
# inner ot  0.042225
# inner ot  0.04225
# inner ot  0.042275
# inner ot  0.0423
# inner ot  0.042325
# inner ot  0.04235
# inner ot  0.042375
# inner ot  0.0424
# inner ot  0.042425
# inner ot  0.04245
# inner ot  0.042475
# inner ot  0.0425
# inner ot  0.042525
# inner ot  0.04255
# inner ot  0.042575
# inner ot  0.0426
# inner ot  0.042625
# inner ot  0.04265
# inner ot  0.042675
# inner ot  0.0427
# inner ot  0.042725
# inner ot  0.04275
# inner ot  0.042775
# inner ot  0.0428
# inner ot  0.042825
# inner ot  0.04285
# inner ot  0.042875
# inner ot  0.0429
# inner ot  0.042925
# inner ot  0.04295
# inner ot  0.042975
# inner ot  0.043
# inner ot  0.043025
# inner ot  0.04305
# inner ot  0.043075
# inner ot  0.0431
# inner ot  0.043125
# inner ot  0.04315
# inner ot  0.043175
# inner ot  0.0432
# inner ot  0.043225
# inner ot  0.04325
# inner ot  0.043275
# inner ot  0.0433
# inner ot  0.043325
# inner ot  0.04335
# inner ot  0.043375
# inner ot  0.0434
# inner ot  0.043425
# inner ot  0.04345
# inner ot  0.043475
# inner ot  0.0435
# inner ot  0.043525
# inner ot  0.04355
# inner ot  0.043575
# inner ot  0.0436
# inner ot  0.043625
# inner ot  0.04365
# inner ot  0.043675
# inner ot  0.0437
# inner ot  0.043725
# inner ot  0.04375
# inner ot  0.043775
# inner ot  0.0438
# inner ot  0.043825
# inner ot  0.04385
# inner ot  0.043875
# inner ot  0.0439
# inner ot  0.043925
# inner ot  0.04395
# inner ot  0.043975
# inner ot  0.044
# inner ot  0.044025
# inner ot  0.04405
# inner ot  0.044075
# inner ot  0.0441
# inner ot  0.044125
# inner ot  0.04415
# inner ot  0.044175
# inner ot  0.0442
# inner ot  0.044225
# inner ot  0.04425
# inner ot  0.044275
# inner ot  0.0443
# inner ot  0.044325
# inner ot  0.04435
# inner ot  0.044375
# inner ot  0.0444
# inner ot  0.044425
# inner ot  0.04445
# inner ot  0.044475
# inner ot  0.0445
# inner ot  0.044525
# inner ot  0.04455
# inner ot  0.044575
# inner ot  0.0446
# inner ot  0.044625
# inner ot  0.04465
# inner ot  0.044675
# inner ot  0.0447
# inner ot  0.044725
# inner ot  0.04475
# inner ot  0.044775
# inner ot  0.0448
# inner ot  0.044825
# inner ot  0.04485
# inner ot  0.044875
# inner ot  0.0449
# inner ot  0.044925
# inner ot  0.04495
# inner ot  0.044975
# inner ot  0.045
# inner ot  0.045025
# inner ot  0.04505
# inner ot  0.045075
# inner ot  0.0451
# inner ot  0.045125
# inner ot  0.04515
# inner ot  0.045175
# inner ot  0.0452
# inner ot  0.045225
# inner ot  0.04525
# inner ot  0.045275
# inner ot  0.0453
# inner ot  0.045325
# inner ot  0.04535
# inner ot  0.045375
# inner ot  0.0454
# inner ot  0.045425
# inner ot  0.04545
# inner ot  0.045475
# inner ot  0.0455
# inner ot  0.045525
# inner ot  0.04555
# inner ot  0.045575
# inner ot  0.0456
# inner ot  0.045625
# inner ot  0.04565
# inner ot  0.045675
# inner ot  0.0457
# inner ot  0.045725
# inner ot  0.04575
# inner ot  0.045775
# inner ot  0.0458
# inner ot  0.045825
# inner ot  0.04585
# inner ot  0.045875
# inner ot  0.0459
# inner ot  0.045925
# inner ot  0.04595
# inner ot  0.045975
# inner ot  0.046
# inner ot  0.046025
# inner ot  0.04605
# inner ot  0.046075
# inner ot  0.0461
# inner ot  0.046125
# inner ot  0.04615
# inner ot  0.046175
# inner ot  0.0462
# inner ot  0.046225
# inner ot  0.04625
# inner ot  0.046275
# inner ot  0.0463
# inner ot  0.046325
# inner ot  0.04635
# inner ot  0.046375
# inner ot  0.0464
# inner ot  0.046425
# inner ot  0.04645
# inner ot  0.046475
# inner ot  0.0465
# inner ot  0.046525
# inner ot  0.04655
# inner ot  0.046575
# inner ot  0.0466
# inner ot  0.046625
# inner ot  0.04665
# inner ot  0.046675
# inner ot  0.0467
# inner ot  0.046725
# inner ot  0.04675
# inner ot  0.046775
# inner ot  0.0468
# inner ot  0.046825
# inner ot  0.04685
# inner ot  0.046875
# inner ot  0.0469
# inner ot  0.046925
# inner ot  0.04695
# inner ot  0.046975
# inner ot  0.047
# inner ot  0.047025
# inner ot  0.04705
# inner ot  0.047075
# inner ot  0.0471
# inner ot  0.047125
# inner ot  0.04715
# inner ot  0.047175
# inner ot  0.0472
# inner ot  0.047225
# inner ot  0.04725
# inner ot  0.047275
# inner ot  0.0473
# inner ot  0.047325
# inner ot  0.04735
# inner ot  0.047375
# inner ot  0.0474
# inner ot  0.047425
# inner ot  0.04745
# inner ot  0.047475
# inner ot  0.0475
# inner ot  0.047525
# inner ot  0.04755
# inner ot  0.047575
# inner ot  0.0476
# inner ot  0.047625
# inner ot  0.04765
# inner ot  0.047675
# inner ot  0.0477
# inner ot  0.047725
# inner ot  0.04775
# inner ot  0.047775
# inner ot  0.0478
# inner ot  0.047825
# inner ot  0.04785
# inner ot  0.047875
# inner ot  0.0479
# inner ot  0.047925
# inner ot  0.04795
# inner ot  0.047975
# inner ot  0.048
# inner ot  0.048025
# inner ot  0.04805
# inner ot  0.048075
# inner ot  0.0481
# inner ot  0.048125
# inner ot  0.04815
# inner ot  0.048175
# inner ot  0.0482
# inner ot  0.048225
# inner ot  0.04825
# inner ot  0.048275
# inner ot  0.0483
# inner ot  0.048325
# inner ot  0.04835
# inner ot  0.048375
# inner ot  0.0484
# inner ot  0.048425
# inner ot  0.04845
# inner ot  0.048475
# inner ot  0.0485
# inner ot  0.048525
# inner ot  0.04855
# inner ot  0.048575
# inner ot  0.0486
# inner ot  0.048625
# inner ot  0.04865
# inner ot  0.048675
# inner ot  0.0487
# inner ot  0.048725
# inner ot  0.04875
# inner ot  0.048775
# inner ot  0.0488
# inner ot  0.048825
# inner ot  0.04885
# inner ot  0.048875
# inner ot  0.0489
# inner ot  0.048925
# inner ot  0.04895
# inner ot  0.048975
# inner ot  0.049
# inner ot  0.049025
# inner ot  0.04905
# inner ot  0.049075
# inner ot  0.0491
# inner ot  0.049125
# inner ot  0.04915
# inner ot  0.049175
# inner ot  0.0492
# inner ot  0.049225
# inner ot  0.04925
# inner ot  0.049275
# inner ot  0.0493
# inner ot  0.049325
# inner ot  0.04935
# inner ot  0.049375
# inner ot  0.0494
# inner ot  0.049425
# inner ot  0.04945
# inner ot  0.049475
# inner ot  0.0495
# inner ot  0.049525
# inner ot  0.04955
# inner ot  0.049575
# inner ot  0.0496
# inner ot  0.049625
# inner ot  0.04965
# inner ot  0.049675
# inner ot  0.0497
# inner ot  0.049725
# inner ot  0.04975
# inner ot  0.049775
# inner ot  0.0498
# inner ot  0.049825
# inner ot  0.04985
# inner ot  0.049875
# inner ot  0.0499
# inner ot  0.049925
# inner ot  0.04995
# inner ot  0.049975
# inner ot  0.05
# inner ot  0.050025
# inner ot  0.05005
# inner ot  0.050075
# inner ot  0.0501
# inner ot  0.050125
# inner ot  0.05015
# inner ot  0.050175
# inner ot  0.0502
# inner ot  0.050225
# inner ot  0.05025
# inner ot  0.050275
# inner ot  0.0503
# inner ot  0.050325
# inner ot  0.05035
# inner ot  0.050375
# inner ot  0.0504
# inner ot  0.050425
# inner ot  0.05045
# inner ot  0.050475
# inner ot  0.0505
# inner ot  0.050525
# inner ot  0.05055
# inner ot  0.050575
# inner ot  0.0506
# inner ot  0.050625
# inner ot  0.05065
# inner ot  0.050675
# inner ot  0.0507
# inner ot  0.050725
# inner ot  0.05075
# inner ot  0.050775
# inner ot  0.0508
# inner ot  0.050825
# inner ot  0.05085
# inner ot  0.050875
# inner ot  0.0509
# inner ot  0.050925
# inner ot  0.05095
# inner ot  0.050975
# inner ot  0.051
# inner ot  0.051025
# inner ot  0.05105
# inner ot  0.051075
# inner ot  0.0511
# inner ot  0.051125
# inner ot  0.05115
# inner ot  0.051175
# inner ot  0.0512
# inner ot  0.051225
# inner ot  0.05125
# inner ot  0.051275
# inner ot  0.0513
# inner ot  0.051325
# inner ot  0.05135
# inner ot  0.051375
# inner ot  0.0514
# inner ot  0.051425
# inner ot  0.05145
# inner ot  0.051475
# inner ot  0.0515
# inner ot  0.051525
# inner ot  0.05155
# inner ot  0.051575
# inner ot  0.0516
# inner ot  0.051625
# inner ot  0.05165
# inner ot  0.051675
# inner ot  0.0517
# inner ot  0.051725
# inner ot  0.05175
# inner ot  0.051775
# inner ot  0.0518
# inner ot  0.051825
# inner ot  0.05185
# inner ot  0.051875
# inner ot  0.0519
# inner ot  0.051925
# inner ot  0.05195
# inner ot  0.051975
# inner ot  0.052
# inner ot  0.052025
# inner ot  0.05205
# inner ot  0.052075
# inner ot  0.0521
# inner ot  0.052125
# inner ot  0.05215
# inner ot  0.052175
# inner ot  0.0522
# inner ot  0.052225
# inner ot  0.05225
# inner ot  0.052275
# inner ot  0.0523
# inner ot  0.052325
# inner ot  0.05235
# inner ot  0.052375
# inner ot  0.0524
# inner ot  0.052425
# inner ot  0.05245
# inner ot  0.052475
# inner ot  0.0525
# inner ot  0.052525
# inner ot  0.05255
# inner ot  0.052575
# inner ot  0.0526
# inner ot  0.052625
# inner ot  0.05265
# inner ot  0.052675
# inner ot  0.0527
# inner ot  0.052725
# inner ot  0.05275
# inner ot  0.052775
# inner ot  0.0528
# inner ot  0.052825
# inner ot  0.05285
# inner ot  0.052875
# inner ot  0.0529
# inner ot  0.052925
# inner ot  0.05295
# inner ot  0.052975
# inner ot  0.053
# inner ot  0.053025
# inner ot  0.05305
# inner ot  0.053075
# inner ot  0.0531
# inner ot  0.053125
# inner ot  0.05315
# inner ot  0.053175
# inner ot  0.0532
# inner ot  0.053225
# inner ot  0.05325
# inner ot  0.053275
# inner ot  0.0533
# inner ot  0.053325
# inner ot  0.05335
# inner ot  0.053375
# inner ot  0.0534
# inner ot  0.053425
# inner ot  0.05345
# inner ot  0.053475
# inner ot  0.0535
# inner ot  0.053525
# inner ot  0.05355
# inner ot  0.053575
# inner ot  0.0536
# inner ot  0.053625
# inner ot  0.05365
# inner ot  0.053675
# inner ot  0.0537
# inner ot  0.053725
# inner ot  0.05375
# inner ot  0.053775
# inner ot  0.0538
# inner ot  0.053825
# inner ot  0.05385
# inner ot  0.053875
# inner ot  0.0539
# inner ot  0.053925
# inner ot  0.05395
# inner ot  0.053975
# inner ot  0.054
# inner ot  0.054025
# inner ot  0.05405
# inner ot  0.054075
# inner ot  0.0541
# inner ot  0.054125
# inner ot  0.05415
# inner ot  0.054175
# inner ot  0.0542
# inner ot  0.054225
# inner ot  0.05425
# inner ot  0.054275
# inner ot  0.0543
# inner ot  0.054325
# inner ot  0.05435
# inner ot  0.054375
# inner ot  0.0544
# inner ot  0.054425
# inner ot  0.05445
# inner ot  0.054475
# inner ot  0.0545
# inner ot  0.054525
# inner ot  0.05455
# inner ot  0.054575
# inner ot  0.0546
# inner ot  0.054625
# inner ot  0.05465
# inner ot  0.054675
# inner ot  0.0547
# inner ot  0.054725
# inner ot  0.05475
# inner ot  0.054775
# inner ot  0.0548
# inner ot  0.054825
# inner ot  0.05485
# inner ot  0.054875
# inner ot  0.0549
# inner ot  0.054925
# inner ot  0.05495
# inner ot  0.054975
# inner ot  0.055
# inner ot  0.055025
# inner ot  0.05505
# inner ot  0.055075
# inner ot  0.0551
# inner ot  0.055125
# inner ot  0.05515
# inner ot  0.055175
# inner ot  0.0552
# inner ot  0.055225
# inner ot  0.05525
# inner ot  0.055275
# inner ot  0.0553
# inner ot  0.055325
# inner ot  0.05535
# inner ot  0.055375
# inner ot  0.0554
# inner ot  0.055425
# inner ot  0.05545
# inner ot  0.055475
# inner ot  0.0555
# inner ot  0.055525
# inner ot  0.05555
# inner ot  0.055575
# inner ot  0.0556
# inner ot  0.055625
# inner ot  0.05565
# inner ot  0.055675
# inner ot  0.0557
# inner ot  0.055725
# inner ot  0.05575
# inner ot  0.055775
# inner ot  0.0558
# inner ot  0.055825
# inner ot  0.05585
# inner ot  0.055875
# inner ot  0.0559
# inner ot  0.055925
# inner ot  0.05595
# inner ot  0.055975
# inner ot  0.056
# inner ot  0.056025
# inner ot  0.05605
# inner ot  0.056075
# inner ot  0.0561
# inner ot  0.056125
# inner ot  0.05615
# inner ot  0.056175
# inner ot  0.0562
# inner ot  0.056225
# inner ot  0.05625
# inner ot  0.056275
# inner ot  0.0563
# inner ot  0.056325
# inner ot  0.05635
# inner ot  0.056375
# inner ot  0.0564
# inner ot  0.056425
# inner ot  0.05645
# inner ot  0.056475
# inner ot  0.0565
# inner ot  0.056525
# inner ot  0.05655
# inner ot  0.056575
# inner ot  0.0566
# inner ot  0.056625
# inner ot  0.05665
# inner ot  0.056675
# inner ot  0.0567
# inner ot  0.056725
# inner ot  0.05675
# inner ot  0.056775
# inner ot  0.0568
# inner ot  0.056825
# inner ot  0.05685
# inner ot  0.056875
# inner ot  0.0569
# inner ot  0.056925
# inner ot  0.05695
# inner ot  0.056975
# inner ot  0.057
# inner ot  0.057025
# inner ot  0.05705
# inner ot  0.057075
# inner ot  0.0571
# inner ot  0.057125
# inner ot  0.05715
# inner ot  0.057175
# inner ot  0.0572
# inner ot  0.057225
# inner ot  0.05725
# inner ot  0.057275
# inner ot  0.0573
# inner ot  0.057325
# inner ot  0.05735
# inner ot  0.057375
# inner ot  0.0574
# inner ot  0.057425
# inner ot  0.05745
# inner ot  0.057475
# inner ot  0.0575
# inner ot  0.057525
# inner ot  0.05755
# inner ot  0.057575
# inner ot  0.0576
# inner ot  0.057625
# inner ot  0.05765
# inner ot  0.057675
# inner ot  0.0577
# inner ot  0.057725
# inner ot  0.05775
# inner ot  0.057775
# inner ot  0.0578
# inner ot  0.057825
# inner ot  0.05785
# inner ot  0.057875
# inner ot  0.0579
# inner ot  0.057925
# inner ot  0.05795
# inner ot  0.057975
# inner ot  0.058
# inner ot  0.058025
# inner ot  0.05805
# inner ot  0.058075
# inner ot  0.0581
# inner ot  0.058125
# inner ot  0.05815
# inner ot  0.058175
# inner ot  0.0582
# inner ot  0.058225
# inner ot  0.05825
# inner ot  0.058275
# inner ot  0.0583
# inner ot  0.058325
# inner ot  0.05835
# inner ot  0.058375
# inner ot  0.0584
# inner ot  0.058425
# inner ot  0.05845
# inner ot  0.058475
# inner ot  0.0585
# inner ot  0.058525
# inner ot  0.05855
# inner ot  0.058575
# inner ot  0.0586
# inner ot  0.058625
# inner ot  0.05865
# inner ot  0.058675
# inner ot  0.0587
# inner ot  0.058725
# inner ot  0.05875
# inner ot  0.058775
# inner ot  0.0588
# inner ot  0.058825
# inner ot  0.05885
# inner ot  0.058875
# inner ot  0.0589
# inner ot  0.058925
# inner ot  0.05895
# inner ot  0.058975
# inner ot  0.059
# inner ot  0.059025
# inner ot  0.05905
# inner ot  0.059075
# inner ot  0.0591
# inner ot  0.059125
# inner ot  0.05915
# inner ot  0.059175
# inner ot  0.0592
# inner ot  0.059225
# inner ot  0.05925
# inner ot  0.059275
# inner ot  0.0593
# inner ot  0.059325
# inner ot  0.05935
# inner ot  0.059375
# inner ot  0.0594
# inner ot  0.059425
# inner ot  0.05945
# inner ot  0.059475
# inner ot  0.0595
# inner ot  0.059525
# inner ot  0.05955
# inner ot  0.059575
# inner ot  0.0596
# inner ot  0.059625
# inner ot  0.05965
# inner ot  0.059675
# inner ot  0.0597
# inner ot  0.059725
# inner ot  0.05975
# inner ot  0.059775
# inner ot  0.0598
# inner ot  0.059825
# inner ot  0.05985
# inner ot  0.059875
# inner ot  0.0599
# inner ot  0.059925
# inner ot  0.05995
# inner ot  0.059975
# inner ot  0.06
# inner ot  0.060025
# inner ot  0.06005
# inner ot  0.060075
# inner ot  0.0601
# inner ot  0.060125
# inner ot  0.06015
# inner ot  0.060175
# inner ot  0.0602
# inner ot  0.060225
# inner ot  0.06025
# inner ot  0.060275
# inner ot  0.0603
# inner ot  0.060325
# inner ot  0.06035
# inner ot  0.060375
# inner ot  0.0604
# inner ot  0.060425
# inner ot  0.06045
# inner ot  0.060475
# inner ot  0.0605
# inner ot  0.060525
# inner ot  0.06055
# inner ot  0.060575
# inner ot  0.0606
# inner ot  0.060625
# inner ot  0.06065
# inner ot  0.060675
# inner ot  0.0607
# inner ot  0.060725
# inner ot  0.06075
# inner ot  0.060775
# inner ot  0.0608
# inner ot  0.060825
# inner ot  0.06085
# inner ot  0.060875
# inner ot  0.0609
# inner ot  0.060925
# inner ot  0.06095
# inner ot  0.060975
# inner ot  0.061
# inner ot  0.061025
# inner ot  0.06105
# inner ot  0.061075
# inner ot  0.0611
# inner ot  0.061125
# inner ot  0.06115
# inner ot  0.061175
# inner ot  0.0612
# inner ot  0.061225
# inner ot  0.06125
# inner ot  0.061275
# inner ot  0.0613
# inner ot  0.061325
# inner ot  0.06135
# inner ot  0.061375
# inner ot  0.0614
# inner ot  0.061425
# inner ot  0.06145
# inner ot  0.061475
# inner ot  0.0615
# inner ot  0.061525
# inner ot  0.06155
# inner ot  0.061575
# inner ot  0.0616
# inner ot  0.061625
# inner ot  0.06165
# inner ot  0.061675
# inner ot  0.0617
# inner ot  0.061725
# inner ot  0.06175
# inner ot  0.061775
# inner ot  0.0618
# inner ot  0.061825
# inner ot  0.06185
# inner ot  0.061875
# inner ot  0.0619
# inner ot  0.061925
# inner ot  0.06195
# inner ot  0.061975
# inner ot  0.062
# inner ot  0.062025
# inner ot  0.06205
# inner ot  0.062075
# inner ot  0.0621
# inner ot  0.062125
# inner ot  0.06215
# inner ot  0.062175
# inner ot  0.0622
# inner ot  0.062225
# inner ot  0.06225
# inner ot  0.062275
# inner ot  0.0623
# inner ot  0.062325
# inner ot  0.06235
# inner ot  0.062375
# inner ot  0.0624
# inner ot  0.062425
# inner ot  0.06245
# inner ot  0.062475
# inner ot  0.0625
# inner ot  0.062525
# inner ot  0.06255
# inner ot  0.062575
# inner ot  0.0626
# inner ot  0.062625
# inner ot  0.06265
# inner ot  0.062675
# inner ot  0.0627
# inner ot  0.062725
# inner ot  0.06275
# inner ot  0.062775
# inner ot  0.0628
# inner ot  0.062825
# inner ot  0.06285
# inner ot  0.062875
# inner ot  0.0629
# inner ot  0.062925
# inner ot  0.06295
# inner ot  0.062975
# inner ot  0.063
# inner ot  0.063025
# inner ot  0.06305
# inner ot  0.063075
# inner ot  0.0631
# inner ot  0.063125
# inner ot  0.06315
# inner ot  0.063175
# inner ot  0.0632
# inner ot  0.063225
# inner ot  0.06325
# inner ot  0.063275
# inner ot  0.0633
# inner ot  0.063325
# inner ot  0.06335
# inner ot  0.063375
# inner ot  0.0634
# inner ot  0.063425
# inner ot  0.06345
# inner ot  0.063475
# inner ot  0.0635
# inner ot  0.063525
# inner ot  0.06355
# inner ot  0.063575
# inner ot  0.0636
# inner ot  0.063625
# inner ot  0.06365
# inner ot  0.063675
# inner ot  0.0637
# inner ot  0.063725
# inner ot  0.06375
# inner ot  0.063775
# inner ot  0.0638
# inner ot  0.063825
# inner ot  0.06385
# inner ot  0.063875
# inner ot  0.0639
# inner ot  0.063925
# inner ot  0.06395
# inner ot  0.063975
# inner ot  0.064
# inner ot  0.064025
# inner ot  0.06405
# inner ot  0.064075
# inner ot  0.0641
# inner ot  0.064125
# inner ot  0.06415
# inner ot  0.064175
# inner ot  0.0642
# inner ot  0.064225
# inner ot  0.06425
# inner ot  0.064275
# inner ot  0.0643
# inner ot  0.064325
# inner ot  0.06435
# inner ot  0.064375
# inner ot  0.0644
# inner ot  0.064425
# inner ot  0.06445
# inner ot  0.064475
# inner ot  0.0645
# inner ot  0.064525
# inner ot  0.06455
# inner ot  0.064575
# inner ot  0.0646
# inner ot  0.064625
# inner ot  0.06465
# inner ot  0.064675
# inner ot  0.0647
# inner ot  0.064725
# inner ot  0.06475
# inner ot  0.064775
# inner ot  0.0648
# inner ot  0.064825
# inner ot  0.06485
# inner ot  0.064875
# inner ot  0.0649
# inner ot  0.064925
# inner ot  0.06495
# inner ot  0.064975
# inner ot  0.065
# inner ot  0.065025
# inner ot  0.06505
# inner ot  0.065075
# inner ot  0.0651
# inner ot  0.065125
# inner ot  0.06515
# inner ot  0.065175
# inner ot  0.0652
# inner ot  0.065225
# inner ot  0.06525
# inner ot  0.065275
# inner ot  0.0653
# inner ot  0.065325
# inner ot  0.06535
# inner ot  0.065375
# inner ot  0.0654
# inner ot  0.065425
# inner ot  0.06545
# inner ot  0.065475
# inner ot  0.0655
# inner ot  0.065525
# inner ot  0.06555
# inner ot  0.065575
# inner ot  0.0656
# inner ot  0.065625
# inner ot  0.06565
# inner ot  0.065675
# inner ot  0.0657
# inner ot  0.065725
# inner ot  0.06575
# inner ot  0.065775
# inner ot  0.0658
# inner ot  0.065825
# ...
# inner ot  0.980125
# inner ot  0.98015
# inner ot  0.980175
# inner ot  0.9802
# inner ot  0.980225
# inner ot  0.98025
# inner ot  0.980275
# inner ot  0.9803
# inner ot  0.980325
# inner ot  0.98035
# inner ot  0.980375
# inner ot  0.9804
# inner ot  0.980425
# inner ot  0.98045
# inner ot  0.980475
# inner ot  0.9805
# inner ot  0.980525
# inner ot  0.98055
# inner ot  0.980575
# inner ot  0.9806
# inner ot  0.980625
# inner ot  0.98065
# inner ot  0.980675
# inner ot  0.9807
# inner ot  0.980725
# inner ot  0.98075
# inner ot  0.980775
# inner ot  0.9808
# inner ot  0.980825
# inner ot  0.98085
# inner ot  0.980875
# inner ot  0.9809
# inner ot  0.980925
# inner ot  0.98095
# inner ot  0.980975
# inner ot  0.981
# inner ot  0.981025
# inner ot  0.98105
# inner ot  0.981075
# inner ot  0.9811
# inner ot  0.981125
# inner ot  0.98115
# inner ot  0.981175
# inner ot  0.9812
# inner ot  0.981225
# inner ot  0.98125
# inner ot  0.981275
# inner ot  0.9813
# inner ot  0.981325
# inner ot  0.98135
# inner ot  0.981375
# inner ot  0.9814
# inner ot  0.981425
# inner ot  0.98145
# inner ot  0.981475
# inner ot  0.9815
# inner ot  0.981525
# inner ot  0.98155
# inner ot  0.981575
# inner ot  0.9816
# inner ot  0.981625
# inner ot  0.98165
# inner ot  0.981675
# inner ot  0.9817
# inner ot  0.981725
# inner ot  0.98175
# inner ot  0.981775
# inner ot  0.9818
# inner ot  0.981825
# inner ot  0.98185
# inner ot  0.981875
# inner ot  0.9819
# inner ot  0.981925
# inner ot  0.98195
# inner ot  0.981975
# inner ot  0.982
# inner ot  0.982025
# inner ot  0.98205
# inner ot  0.982075
# inner ot  0.9821
# inner ot  0.982125
# inner ot  0.98215
# inner ot  0.982175
# inner ot  0.9822
# inner ot  0.982225
# inner ot  0.98225
# inner ot  0.982275
# inner ot  0.9823
# inner ot  0.982325
# inner ot  0.98235
# inner ot  0.982375
# inner ot  0.9824
# inner ot  0.982425
# inner ot  0.98245
# inner ot  0.982475
# inner ot  0.9825
# inner ot  0.982525
# inner ot  0.98255
# inner ot  0.982575
# inner ot  0.9826
# inner ot  0.982625
# inner ot  0.98265
# inner ot  0.982675
# inner ot  0.9827
# inner ot  0.982725
# inner ot  0.98275
# inner ot  0.982775
# inner ot  0.9828
# inner ot  0.982825
# inner ot  0.98285
# inner ot  0.982875
# inner ot  0.9829
# inner ot  0.982925
# inner ot  0.98295
# inner ot  0.982975
# inner ot  0.983
# inner ot  0.983025
# inner ot  0.98305
# inner ot  0.983075
# inner ot  0.9831
# inner ot  0.983125
# inner ot  0.98315
# inner ot  0.983175
# inner ot  0.9832
# inner ot  0.983225
# inner ot  0.98325
# inner ot  0.983275
# inner ot  0.9833
# inner ot  0.983325
# inner ot  0.98335
# inner ot  0.983375
# inner ot  0.9834
# inner ot  0.983425
# inner ot  0.98345
# inner ot  0.983475
# inner ot  0.9835
# inner ot  0.983525
# inner ot  0.98355
# inner ot  0.983575
# inner ot  0.9836
# inner ot  0.983625
# inner ot  0.98365
# inner ot  0.983675
# inner ot  0.9837
# inner ot  0.983725
# inner ot  0.98375
# inner ot  0.983775
# inner ot  0.9838
# inner ot  0.983825
# inner ot  0.98385
# inner ot  0.983875
# inner ot  0.9839
# inner ot  0.983925
# inner ot  0.98395
# inner ot  0.983975
# inner ot  0.984
# inner ot  0.984025
# inner ot  0.98405
# inner ot  0.984075
# inner ot  0.9841
# inner ot  0.984125
# inner ot  0.98415
# inner ot  0.984175
# inner ot  0.9842
# inner ot  0.984225
# inner ot  0.98425
# inner ot  0.984275
# inner ot  0.9843
# inner ot  0.984325
# inner ot  0.98435
# inner ot  0.984375
# inner ot  0.9844
# inner ot  0.984425
# inner ot  0.98445
# inner ot  0.984475
# inner ot  0.9845
# inner ot  0.984525
# inner ot  0.98455
# inner ot  0.984575
# inner ot  0.9846
# inner ot  0.984625
# inner ot  0.98465
# inner ot  0.984675
# inner ot  0.9847
# inner ot  0.984725
# inner ot  0.98475
# inner ot  0.984775
# inner ot  0.9848
# inner ot  0.984825
# inner ot  0.98485
# inner ot  0.984875
# inner ot  0.9849
# inner ot  0.984925
# inner ot  0.98495
# inner ot  0.984975
# inner ot  0.985
# inner ot  0.985025
# inner ot  0.98505
# inner ot  0.985075
# inner ot  0.9851
# inner ot  0.985125
# inner ot  0.98515
# inner ot  0.985175
# inner ot  0.9852
# inner ot  0.985225
# inner ot  0.98525
# inner ot  0.985275
# inner ot  0.9853
# inner ot  0.985325
# inner ot  0.98535
# inner ot  0.985375
# inner ot  0.9854
# inner ot  0.985425
# inner ot  0.98545
# inner ot  0.985475
# inner ot  0.9855
# inner ot  0.985525
# inner ot  0.98555
# inner ot  0.985575
# inner ot  0.9856
# inner ot  0.985625
# inner ot  0.98565
# inner ot  0.985675
# inner ot  0.9857
# inner ot  0.985725
# inner ot  0.98575
# inner ot  0.985775
# inner ot  0.9858
# inner ot  0.985825
# inner ot  0.98585
# inner ot  0.985875
# inner ot  0.9859
# inner ot  0.985925
# inner ot  0.98595
# inner ot  0.985975
# inner ot  0.986
# inner ot  0.986025
# inner ot  0.98605
# inner ot  0.986075
# inner ot  0.9861
# inner ot  0.986125
# inner ot  0.98615
# inner ot  0.986175
# inner ot  0.9862
# inner ot  0.986225
# inner ot  0.98625
# inner ot  0.986275
# inner ot  0.9863
# inner ot  0.986325
# inner ot  0.98635
# inner ot  0.986375
# inner ot  0.9864
# inner ot  0.986425
# inner ot  0.98645
# inner ot  0.986475
# inner ot  0.9865
# inner ot  0.986525
# inner ot  0.98655
# inner ot  0.986575
# inner ot  0.9866
# inner ot  0.986625
# inner ot  0.98665
# inner ot  0.986675
# inner ot  0.9867
# inner ot  0.986725
# inner ot  0.98675
# inner ot  0.986775
# inner ot  0.9868
# inner ot  0.986825
# inner ot  0.98685
# inner ot  0.986875
# inner ot  0.9869
# inner ot  0.986925
# inner ot  0.98695
# inner ot  0.986975
# inner ot  0.987
# inner ot  0.987025
# inner ot  0.98705
# inner ot  0.987075
# inner ot  0.9871
# inner ot  0.987125
# inner ot  0.98715
# inner ot  0.987175
# inner ot  0.9872
# inner ot  0.987225
# inner ot  0.98725
# inner ot  0.987275
# inner ot  0.9873
# inner ot  0.987325
# inner ot  0.98735
# inner ot  0.987375
# inner ot  0.9874
# inner ot  0.987425
# inner ot  0.98745
# inner ot  0.987475
# inner ot  0.9875
# inner ot  0.987525
# inner ot  0.98755
# inner ot  0.987575
# inner ot  0.9876
# inner ot  0.987625
# inner ot  0.98765
# inner ot  0.987675
# inner ot  0.9877
# inner ot  0.987725
# inner ot  0.98775
# inner ot  0.987775
# inner ot  0.9878
# inner ot  0.987825
# inner ot  0.98785
# inner ot  0.987875
# inner ot  0.9879
# inner ot  0.987925
# inner ot  0.98795
# inner ot  0.987975
# inner ot  0.988
# inner ot  0.988025
# inner ot  0.98805
# inner ot  0.988075
# inner ot  0.9881
# inner ot  0.988125
# inner ot  0.98815
# inner ot  0.988175
# inner ot  0.9882
# inner ot  0.988225
# inner ot  0.98825
# inner ot  0.988275
# inner ot  0.9883
# inner ot  0.988325
# inner ot  0.98835
# inner ot  0.988375
# inner ot  0.9884
# inner ot  0.988425
# inner ot  0.98845
# inner ot  0.988475
# inner ot  0.9885
# inner ot  0.988525
# inner ot  0.98855
# inner ot  0.988575
# inner ot  0.9886
# inner ot  0.988625
# inner ot  0.98865
# inner ot  0.988675
# inner ot  0.9887
# inner ot  0.988725
# inner ot  0.98875
# inner ot  0.988775
# inner ot  0.9888
# inner ot  0.988825
# inner ot  0.98885
# inner ot  0.988875
# inner ot  0.9889
# inner ot  0.988925
# inner ot  0.98895
# inner ot  0.988975
# inner ot  0.989
# inner ot  0.989025
# inner ot  0.98905
# inner ot  0.989075
# inner ot  0.9891
# inner ot  0.989125
# inner ot  0.98915
# inner ot  0.989175
# inner ot  0.9892
# inner ot  0.989225
# inner ot  0.98925
# inner ot  0.989275
# inner ot  0.9893
# inner ot  0.989325
# inner ot  0.98935
# inner ot  0.989375
# inner ot  0.9894
# inner ot  0.989425
# inner ot  0.98945
# inner ot  0.989475
# inner ot  0.9895
# inner ot  0.989525
# inner ot  0.98955
# inner ot  0.989575
# inner ot  0.9896
# inner ot  0.989625
# inner ot  0.98965
# inner ot  0.989675
# inner ot  0.9897
# inner ot  0.989725
# inner ot  0.98975
# inner ot  0.989775
# inner ot  0.9898
# inner ot  0.989825
# inner ot  0.98985
# inner ot  0.989875
# inner ot  0.9899
# inner ot  0.989925
# inner ot  0.98995
# inner ot  0.989975
# inner ot  0.99
# inner ot  0.990025
# inner ot  0.99005
# inner ot  0.990075
# inner ot  0.9901
# inner ot  0.990125
# inner ot  0.99015
# inner ot  0.990175
# inner ot  0.9902
# inner ot  0.990225
# inner ot  0.99025
# inner ot  0.990275
# inner ot  0.9903
# inner ot  0.990325
# inner ot  0.99035
# inner ot  0.990375
# inner ot  0.9904
# inner ot  0.990425
# inner ot  0.99045
# inner ot  0.990475
# inner ot  0.9905
# inner ot  0.990525
# inner ot  0.99055
# inner ot  0.990575
# inner ot  0.9906
# inner ot  0.990625
# inner ot  0.99065
# inner ot  0.990675
# inner ot  0.9907
# inner ot  0.990725
# inner ot  0.99075
# inner ot  0.990775
# inner ot  0.9908
# inner ot  0.990825
# inner ot  0.99085
# inner ot  0.990875
# inner ot  0.9909
# inner ot  0.990925
# inner ot  0.99095
# inner ot  0.990975
# inner ot  0.991
# inner ot  0.991025
# inner ot  0.99105
# inner ot  0.991075
# inner ot  0.9911
# inner ot  0.991125
# inner ot  0.99115
# inner ot  0.991175
# inner ot  0.9912
# inner ot  0.991225
# inner ot  0.99125
# inner ot  0.991275
# inner ot  0.9913
# inner ot  0.991325
# inner ot  0.99135
# inner ot  0.991375
# inner ot  0.9914
# inner ot  0.991425
# inner ot  0.99145
# inner ot  0.991475
# inner ot  0.9915
# inner ot  0.991525
# inner ot  0.99155
# inner ot  0.991575
# inner ot  0.9916
# inner ot  0.991625
# inner ot  0.99165
# inner ot  0.991675
# inner ot  0.9917
# inner ot  0.991725
# inner ot  0.99175
# inner ot  0.991775
# inner ot  0.9918
# inner ot  0.991825
# inner ot  0.99185
# inner ot  0.991875
# inner ot  0.9919
# inner ot  0.991925
# inner ot  0.99195
# inner ot  0.991975
# inner ot  0.992
# inner ot  0.992025
# inner ot  0.99205
# inner ot  0.992075
# inner ot  0.9921
# inner ot  0.992125
# inner ot  0.99215
# inner ot  0.992175
# inner ot  0.9922
# inner ot  0.992225
# inner ot  0.99225
# inner ot  0.992275
# inner ot  0.9923
# inner ot  0.992325
# inner ot  0.99235
# inner ot  0.992375
# inner ot  0.9924
# inner ot  0.992425
# inner ot  0.99245
# inner ot  0.992475
# inner ot  0.9925
# inner ot  0.992525
# inner ot  0.99255
# inner ot  0.992575
# inner ot  0.9926
# inner ot  0.992625
# inner ot  0.99265
# inner ot  0.992675
# inner ot  0.9927
# inner ot  0.992725
# inner ot  0.99275
# inner ot  0.992775
# inner ot  0.9928
# inner ot  0.992825
# inner ot  0.99285
# inner ot  0.992875
# inner ot  0.9929
# inner ot  0.992925
# inner ot  0.99295
# inner ot  0.992975
# inner ot  0.993
# inner ot  0.993025
# inner ot  0.99305
# inner ot  0.993075
# inner ot  0.9931
# inner ot  0.993125
# inner ot  0.99315
# inner ot  0.993175
# inner ot  0.9932
# inner ot  0.993225
# inner ot  0.99325
# inner ot  0.993275
# inner ot  0.9933
# inner ot  0.993325
# inner ot  0.99335
# inner ot  0.993375
# inner ot  0.9934
# inner ot  0.993425
# inner ot  0.99345
# inner ot  0.993475
# inner ot  0.9935
# inner ot  0.993525
# inner ot  0.99355
# inner ot  0.993575
# inner ot  0.9936
# inner ot  0.993625
# inner ot  0.99365
# inner ot  0.993675
# inner ot  0.9937
# inner ot  0.993725
# inner ot  0.99375
# inner ot  0.993775
# inner ot  0.9938
# inner ot  0.993825
# inner ot  0.99385
# inner ot  0.993875
# inner ot  0.9939
# inner ot  0.993925
# inner ot  0.99395
# inner ot  0.993975
# inner ot  0.994
# inner ot  0.994025
# inner ot  0.99405
# inner ot  0.994075
# inner ot  0.9941
# inner ot  0.994125
# inner ot  0.99415
# inner ot  0.994175
# inner ot  0.9942
# inner ot  0.994225
# inner ot  0.99425
# inner ot  0.994275
# inner ot  0.9943
# inner ot  0.994325
# inner ot  0.99435
# inner ot  0.994375
# inner ot  0.9944
# inner ot  0.994425
# inner ot  0.99445
# inner ot  0.994475
# inner ot  0.9945
# inner ot  0.994525
# inner ot  0.99455
# inner ot  0.994575
# inner ot  0.9946
# inner ot  0.994625
# inner ot  0.99465
# inner ot  0.994675
# inner ot  0.9947
# inner ot  0.994725
# inner ot  0.99475
# inner ot  0.994775
# inner ot  0.9948
# inner ot  0.994825
# inner ot  0.99485
# inner ot  0.994875
# inner ot  0.9949
# inner ot  0.994925
# inner ot  0.99495
# inner ot  0.994975
# inner ot  0.995
# inner ot  0.995025
# inner ot  0.99505
# inner ot  0.995075
# inner ot  0.9951
# inner ot  0.995125
# inner ot  0.99515
# inner ot  0.995175
# inner ot  0.9952
# inner ot  0.995225
# inner ot  0.99525
# inner ot  0.995275
# inner ot  0.9953
# inner ot  0.995325
# inner ot  0.99535
# inner ot  0.995375
# inner ot  0.9954
# inner ot  0.995425
# inner ot  0.99545
# inner ot  0.995475
# inner ot  0.9955
# inner ot  0.995525
# inner ot  0.99555
# inner ot  0.995575
# inner ot  0.9956
# inner ot  0.995625
# inner ot  0.99565
# inner ot  0.995675
# inner ot  0.9957
# inner ot  0.995725
# inner ot  0.99575
# inner ot  0.995775
# inner ot  0.9958
# inner ot  0.995825
# inner ot  0.99585
# inner ot  0.995875
# inner ot  0.9959
# inner ot  0.995925
# inner ot  0.99595
# inner ot  0.995975
# inner ot  0.996
# inner ot  0.996025
# inner ot  0.99605
# inner ot  0.996075
# inner ot  0.9961
# inner ot  0.996125
# inner ot  0.99615
# inner ot  0.996175
# inner ot  0.9962
# inner ot  0.996225
# inner ot  0.99625
# inner ot  0.996275
# inner ot  0.9963
# inner ot  0.996325
# inner ot  0.99635
# inner ot  0.996375
# inner ot  0.9964
# inner ot  0.996425
# inner ot  0.99645
# inner ot  0.996475
# inner ot  0.9965
# inner ot  0.996525
# inner ot  0.99655
# inner ot  0.996575
# inner ot  0.9966
# inner ot  0.996625
# inner ot  0.99665
# inner ot  0.996675
# inner ot  0.9967
# inner ot  0.996725
# inner ot  0.99675
# inner ot  0.996775
# inner ot  0.9968
# inner ot  0.996825
# inner ot  0.99685
# inner ot  0.996875
# inner ot  0.9969
# inner ot  0.996925
# inner ot  0.99695
# inner ot  0.996975
# inner ot  0.997
# inner ot  0.997025
# inner ot  0.99705
# inner ot  0.997075
# inner ot  0.9971
# inner ot  0.997125
# inner ot  0.99715
# inner ot  0.997175
# inner ot  0.9972
# inner ot  0.997225
# inner ot  0.99725
# inner ot  0.997275
# inner ot  0.9973
# inner ot  0.997325
# inner ot  0.99735
# inner ot  0.997375
# inner ot  0.9974
# inner ot  0.997425
# inner ot  0.99745
# inner ot  0.997475
# inner ot  0.9975
# inner ot  0.997525
# inner ot  0.99755
# inner ot  0.997575
# inner ot  0.9976
# inner ot  0.997625
# inner ot  0.99765
# inner ot  0.997675
# inner ot  0.9977
# inner ot  0.997725
# inner ot  0.99775
# inner ot  0.997775
# inner ot  0.9978
# inner ot  0.997825
# inner ot  0.99785
# inner ot  0.997875
# inner ot  0.9979
# inner ot  0.997925
# inner ot  0.99795
# inner ot  0.997975
# inner ot  0.998
# inner ot  0.998025
# inner ot  0.99805
# inner ot  0.998075
# inner ot  0.9981
# inner ot  0.998125
# inner ot  0.99815
# inner ot  0.998175
# inner ot  0.9982
# inner ot  0.998225
# inner ot  0.99825
# inner ot  0.998275
# inner ot  0.9983
# inner ot  0.998325
# inner ot  0.99835
# inner ot  0.998375
# inner ot  0.9984
# inner ot  0.998425
# inner ot  0.99845
# inner ot  0.998475
# inner ot  0.9985
# inner ot  0.998525
# inner ot  0.99855
# inner ot  0.998575
# inner ot  0.9986
# inner ot  0.998625
# inner ot  0.99865
# inner ot  0.998675
# inner ot  0.9987
# inner ot  0.998725
# inner ot  0.99875
# inner ot  0.998775
# inner ot  0.9988
# inner ot  0.998825
# inner ot  0.99885
# inner ot  0.998875
# inner ot  0.9989
# inner ot  0.998925
# inner ot  0.99895
# inner ot  0.998975
# inner ot  0.999
# inner ot  0.999025
# inner ot  0.99905
# inner ot  0.999075
# inner ot  0.9991
# inner ot  0.999125
# inner ot  0.99915
# inner ot  0.999175
# inner ot  0.9992
# inner ot  0.999225
# inner ot  0.99925
# inner ot  0.999275
# inner ot  0.9993
# inner ot  0.999325
# inner ot  0.99935
# inner ot  0.999375
# inner ot  0.9994
# inner ot  0.999425
# inner ot  0.99945
# inner ot  0.999475
# inner ot  0.9995
# inner ot  0.999525
# inner ot  0.99955
# inner ot  0.999575
# inner ot  0.9996
# inner ot  0.999625
# inner ot  0.99965
# inner ot  0.999675
# inner ot  0.9997
# inner ot  0.999725
# inner ot  0.99975
# inner ot  0.999775
# inner ot  0.9998
# inner ot  0.999825
# inner ot  0.99985
# inner ot  0.999875
# inner ot  0.9999
# inner ot  0.999925
# inner ot  0.99995
# inner ot  0.999975
# 0.0
# 0.005
# /Users/balazsmorvay/PycharmProjects/NeuroGraph/.venv/lib/python3.13/site-packages/ot/bregman/_sinkhorn.py:630: RuntimeWarning: divide by zero encountered in divide
#   v = b / KtransposeU
# /Users/balazsmorvay/PycharmProjects/NeuroGraph/.venv/lib/python3.13/site-packages/ot/bregman/_sinkhorn.py:642: UserWarning: Warning: numerical errors at iteration 0
#   warnings.warn("Warning: numerical errors at iteration %d" % ii)
# 0.01
# 0.015
# 0.02
# 0.025
# 0.03
# 0.035
# 0.04
# 0.045
# 0.05
# 0.055
# 0.06
# 0.065
# 0.07
# 0.075
# 0.08
# 0.085
# 0.09
# 0.095
# 0.1
# 0.105
# 0.11
# 0.115
# 0.12
# 0.125
# 0.13
# 0.135
# 0.14
# 0.145
# 0.15
# 0.155
# 0.16
# 0.165
# 0.17
# 0.175
# 0.18
# 0.185
# 0.19
# 0.195
# 0.2
# 0.205
# 0.21
# 0.215
# 0.22
# 0.225
# 0.23
# 0.235
# 0.24
# 0.245
# 0.25
# 0.255
# 0.26
# 0.265
# 0.27
# 0.275
# 0.28
# 0.285
# 0.29
# 0.295
# 0.3
# 0.305
# 0.31
# 0.315
# 0.32
# 0.325
# 0.33
# 0.335
# 0.34
# 0.345
# 0.35
# 0.355
# 0.36
# 0.365
# 0.37
# 0.375
# 0.38
# 0.385
# 0.39
# 0.395
# 0.4
# 0.405
# 0.41
# 0.415
# 0.42
# 0.425
# 0.43
# 0.435
# 0.44
# 0.445
# 0.45
# 0.455
# 0.46
# 0.465
# 0.47
# 0.475
# 0.48
# 0.485
# 0.49
# 0.495
# 0.5
# 0.505
# 0.51
# 0.515
# 0.52
# 0.525
# 0.53
# 0.535
# 0.54
# 0.545
# 0.55
# 0.555
# 0.56
# 0.565
# 0.57
# 0.575
# 0.58
# 0.585
# 0.59
# 0.595
# 0.6
# 0.605
# 0.61
# 0.615
# 0.62
# 0.625
# 0.63
# 0.635
# 0.64
# 0.645
# 0.65
# 0.655
# 0.66
# 0.665
# 0.67
# 0.675
# 0.68
# 0.685
# 0.69
# 0.695
# 0.7
# 0.705
# 0.71
# 0.715
# 0.72
# 0.725
# 0.73
# 0.735
# 0.74
# 0.745
# 0.75
# 0.755
# 0.76
# 0.765
# 0.77
# 0.775
# 0.78
# 0.785
# 0.79
# 0.795
# 0.8
# 0.805
# 0.81
# 0.815
# 0.82
# 0.825
# 0.83
# 0.835
# 0.84
# 0.845
# 0.85
# 0.855
# 0.86
# 0.865
# 0.87
# 0.875
# 0.88
# 0.885
# 0.89
# 0.895
# 0.9
# 0.905
# 0.91
# 0.915
# 0.92
# 0.925
# 0.93
# 0.935
# 0.94
# 0.945
# 0.95
# 0.955
# 0.96
# 0.965
# 0.97
# 0.975
# 0.98
# 0.985
# 0.99
# 0.995

# %%
# ----------------------------
# 5) Evaluation helpers
# ----------------------------
@torch.no_grad()
def eval_accuracy(loader):
    model.eval()
    all_y, all_pred = [], []
    for data in loader:
        data = data.to(DEVICE)
        logits = model(data)
        pred = logits.argmax(dim=1).cpu()
        all_pred.append(pred)
        all_y.append(data.y.cpu())
    y_true = torch.cat(all_y)
    y_pred = torch.cat(all_pred)
    return accuracy_score(y_true, y_pred)

# Before adaptation
tgt_acc_before = eval_accuracy(tgt_test_loader)
print(f"Target accuracy BEFORE adaptation ({SOURCE_NAME}→{TARGET_NAME}): {tgt_acc_before:.3f}")
# Out:
# Target accuracy BEFORE adaptation (NCI1→NCI109): 0.627

# %%
src_acc = eval_accuracy(src_loader)
print(f"Source accuracy:  {src_acc:.3f}")
# Out:
# Source accuracy:  0.685

# %%
tgt_acc_after = eval_accuracy(trans_loader)
print(f"Target accuracy AFTER adaptation ({SOURCE_NAME}→{TARGET_NAME}):  {tgt_acc_after:.3f}")
# Out:
# Target accuracy AFTER adaptation (NCI1→NCI109):  0.545
